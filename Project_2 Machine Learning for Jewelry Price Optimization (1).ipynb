# %% [markdown]
# ### 1. Project title: Implement the Jewellery Price Optimisation with Machine Learning; to be able to predict the prices of the jewelry pieces.

# %% [markdown]
# ### 2. Methodology
# The project will be carried out using python and MLFLOW. MLFLOW to be able to track, package, deploy, and manage Machine Learning models in a scalable and reproducible way.

# %% [markdown]
# ### Start coding
# *Step 1: Extract data from the csv file into a Pandas Dataframe
#
# *Step 2: Transform the data (i.e clean the data) - Deal with missing and duplicate data
#
# *step 3: EDA
#
# *step 4: Data preparation
#
# *step 5:Data modelling
#
# *step 6:Model evaluation
#
# *step 7: model deployment

# %% [markdown]
# ### Data Description
# The features contained in the dataset are:
#
# Order datetime: The time at which the order was placed
#
# Order ID: Identifiers for the different orders placed
#
# Purchased product ID: Identifiers for the different product ordered for
#
# Quantity of SKU in the order: Quantity of jewelry pieces ordered for
#
# Category ID: Identifier for the jewelry category
#
# Category alias: Name of jewelry category e.g. earring
#
# Brand ID: Identifier for jeweler brand
#
# Price in USD: Jewelry price in US Dollars
#
# User ID: Identifier for user/customer
#
# Product gender (for male/female) (Target gender for jewelry piece)
#
# Main Color: Overall color of jewelry piece
#
# Main metal: Main metal used for mounting
#
# Main gem: Main gem mounted on jewelry piece

# %%
pip install catboost
# Out:
# Requirement already satisfied: catboost in c:\users\omats\anaconda3\lib\site-packages (1.2.7)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: graphviz in c:\users\omats\anaconda3\lib\site-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in c:\users\omats\anaconda3\lib\site-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in c:\users\omats\anaconda3\lib\site-packages (from catboost) (1.24.3)
# Requirement already satisfied: pandas>=0.24 in c:\users\omats\anaconda3\lib\site-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in c:\users\omats\anaconda3\lib\site-packages (from catboost) (1.10.1)
# Requirement already satisfied: plotly in c:\users\omats\anaconda3\lib\site-packages (from catboost) (5.9.0)
# Requirement already satisfied: six in c:\users\omats\anaconda3\lib\site-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\omats\anaconda3\lib\site-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\omats\anaconda3\lib\site-packages (from pandas>=0.24->catboost) (2022.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\omats\anaconda3\lib\site-packages (from matplotlib->catboost) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\omats\anaconda3\lib\site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\omats\anaconda3\lib\site-packages (from matplotlib->catboost) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\omats\anaconda3\lib\site-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\omats\anaconda3\lib\site-packages (from matplotlib->catboost) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\omats\anaconda3\lib\site-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\omats\anaconda3\lib\site-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\omats\anaconda3\lib\site-packages (from plotly->catboost) (8.2.2)

# %%
pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\omats\anaconda3\lib\site-packages (2.0.1)
# Requirement already satisfied: numpy in c:\users\omats\anaconda3\lib\site-packages (from xgboost) (1.24.3)
# Requirement already satisfied: scipy in c:\users\omats\anaconda3\lib\site-packages (from xgboost) (1.10.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install lightgbm
# Out:
# Requirement already satisfied: lightgbm in c:\users\omats\anaconda3\lib\site-packages (4.5.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.17.0 in c:\users\omats\anaconda3\lib\site-packages (from lightgbm) (1.24.3)
# Requirement already satisfied: scipy in c:\users\omats\anaconda3\lib\site-packages (from lightgbm) (1.10.1)

# %%
# import the necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

import warnings
warnings.filterwarnings('ignore')

#set visualization theme
sns.set()

# %%
# import the dataset
data = pd.read_csv(r"C:\Users\omats\OneDrive\Desktop\Jewelry_Dataset.csv")

data.columns = [
    "Order_Datetime",
    "Order_ID",
    "Product_id",
    "SKU_Quantity",
    "Category_ID",
    "Category",
    "Brand_ID",
    "Price_USD",
    "User_ID",
    "Target_Gender",
    "Main_Color",
    "Main_Metal",
    "Main_Gem",
]

# %%
# peek at the data
data.head(10)
# Out:
#             Order_Datetime      Order_ID    Product_id  SKU_Quantity  \
# 0  2018-12-01 17:38:31 UTC  1.924900e+18  1.806830e+18             1
# 1  2018-12-02 13:53:42 UTC  1.925510e+18  1.842210e+18             1
# 2  2018-12-02 17:44:02 UTC  1.925630e+18  1.835570e+18             1
# 3  2018-12-02 21:30:19 UTC  1.925740e+18  1.873940e+18             1
# 4  2018-12-02 22:09:34 UTC  1.925760e+18  1.835570e+18             1
# 5  2018-12-02 22:09:34 UTC  1.925760e+18  1.600020e+18             1
# 6  2018-12-02 22:16:20 UTC  1.925760e+18  1.835570e+18             1
# 7  2018-12-03 07:03:49 UTC  1.926030e+18  1.811800e+18             1
# 8  2018-12-03 09:48:34 UTC  1.926110e+18  1.836280e+18             1
# 9  2018-12-03 09:48:34 UTC  1.926110e+18  1.877640e+18             1
#
#     Category_ID          Category  Brand_ID  Price_USD       User_ID  \
# 0  1.806830e+18               NaN       NaN     212.14  1.515920e+18
# 1  1.806830e+18   jewelry.pendant       1.0      54.66  1.515920e+18
# 2  1.806830e+18   jewelry.pendant       0.0      88.90  1.515920e+18
# 3  1.806830e+18  jewelry.necklace       0.0     417.67  1.515920e+18
# 4  1.806830e+18   jewelry.earring       1.0     102.27  1.515920e+18
# 5  1.806830e+18   jewelry.earring       0.0     150.55  1.515920e+18
# 6  1.806830e+18   jewelry.earring       0.0      83.42  1.515920e+18
# 7  1.806830e+18   jewelry.pendant       2.0      60.27  1.515920e+18
# 8  1.806830e+18   jewelry.earring       1.0     217.40  1.515920e+18
# 9  1.806830e+18      jewelry.ring       1.0     180.71  1.515920e+18
#
#   Target_Gender Main_Color Main_Metal  Main_Gem
# 0           NaN     yellow       gold       NaN
# 1             f      white       gold  sapphire
# 2             f        red       gold   diamond
# 3           NaN        red       gold  amethyst
# 4           NaN        red       gold       NaN
# 5           NaN        red       gold   diamond
# 6           NaN      white       gold    fianit
# 7             f        red       gold     pearl
# 8           NaN        red       gold   diamond
# 9           NaN      white       gold   diamond

# %%
# Check for missing values
data.isnull().sum()
# Out:
# Order_Datetime        0
# Order_ID              0
# Product_id            0
# SKU_Quantity          0
# Category_ID        5352
# Category           9933
# Brand_ID           4785
# Price_USD          5352
# User_ID            5352
# Target_Gender     48167
# Main_Color         7660
# Main_Metal         5462
# Main_Gem          34058
# dtype: int64

# %%
# Checking how much data is available
data.shape
# Out:
# (95910, 13)

# %%
# feature cardinality
data.nunique()
# Out:
# Order_Datetime    74504
# Order_ID          32909
# Product_id         1706
# SKU_Quantity          1
# Category_ID           2
# Category            218
# Brand_ID             37
# Price_USD          3166
# User_ID             396
# Target_Gender         2
# Main_Color            5
# Main_Metal            3
# Main_Gem             30
# dtype: int64

# %%
# Data description
data.describe()
# Out:
#            Order_ID    Product_id  SKU_Quantity   Category_ID      Brand_ID  \
# count  9.591000e+04  9.591000e+04       95910.0  9.055800e+04  9.112500e+04
# mean   2.485191e+18  1.815968e+18           1.0  1.805948e+18  8.891061e+16
# std    1.934750e+17  2.136788e+17           0.0  2.083947e+16  3.559661e+17
# min    1.924900e+18  1.313550e+18           1.0  1.313680e+18  0.000000e+00
# 25%    2.379732e+18  1.515970e+18           1.0  1.806830e+18  0.000000e+00
# 50%    2.524285e+18  1.956660e+18           1.0  1.806830e+18  1.000000e+00
# 75%    2.644350e+18  1.956660e+18           1.0  1.806830e+18  1.000000e+00
# max    2.719020e+18  2.541960e+18           1.0  1.806830e+18  1.550610e+18
#
#           Price_USD       User_ID
# count  90558.000000  9.055800e+04
# mean     362.213017  1.512648e+18
# std      444.157665  2.374826e+16
# min        0.990000  1.313550e+18
# 25%      145.620000  1.515920e+18
# 50%      258.770000  1.515920e+18
# 75%      431.370000  1.515920e+18
# max    34448.600000  1.554300e+18

# %%
# Data info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95910 entries, 0 to 95909
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order_Datetime  95910 non-null  object
#  1   Order_ID        95910 non-null  float64
#  2   Product_id      95910 non-null  float64
#  3   SKU_Quantity    95910 non-null  int64
#  4   Category_ID     90558 non-null  float64
#  5   Category        85977 non-null  object
#  6   Brand_ID        91125 non-null  float64
#  7   Price_USD       90558 non-null  float64
#  8   User_ID         90558 non-null  float64
#  9   Target_Gender   47743 non-null  object
#  10  Main_Color      88250 non-null  object
#  11  Main_Metal      90448 non-null  object
#  12  Main_Gem        61852 non-null  object
# dtypes: float64(6), int64(1), object(6)
# memory usage: 9.5+ MB

# %%
#Check for Duplicate value
data.duplicated().sum()
# Out:
# 2955

# %%
# features with a cardinality of 1 (invariant features)
invariant_features = data.nunique()[data.nunique()==1].index.tolist()

# %%
invariant_features
# Out:
# ['SKU_Quantity']

# %%
# Check for label distribution
data["Price_USD"].skew()
# Out:
# 18.95906072625981

# %% [markdown]
# ### Observation

# %% [markdown]
# The distribution is right skewed

# %%
# Visualize prize distribution
plt. figure(figsize=(20,15))

sns.kdeplot(data = data, x = "Price_USD")

plt.xlabel("Price in u.s. Dollars")
plt.ylabel("Price Frequency")

plt.tight_layout()
plt.show();plt.close()

# %%
# Target Gender Analysis
data["Target_Gender"].value_counts()
# Out:
# f    47379
# m      364
# Name: Target_Gender, dtype: int64

# %%
data["Target_Gender"].value_counts(normalize = True)
# Out:
# f    0.992376
# m    0.007624
# Name: Target_Gender, dtype: float64

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# ### Observation
# The Female gender significantly out perform the male gender meaning the female bought more of the Jewelry than the male.

# %%
# Visualize Target Gender
plt. figure(figsize=(20,15))

sns.countplot(data = data, x = "Target_Gender")

plt.xlabel("Gender")
plt.ylabel("Gender subpopulation")

plt.show();plt.close()

# %%
# Jewelry category Analysis
data["Category"].value_counts()
# Out:
# jewelry.earring     29051
# jewelry.ring        28300
# jewelry.pendant     13088
# jewelry.bracelet     6188
# 0                    4392
#                     ...
# 626.58                  1
# 13.42                   1
# 2.88                    1
# 101.23                  1
# 253.77                  1
# Name: Category, Length: 218, dtype: int64

# %% [markdown]
# ### Observation
# From above certain Categories does not make sense .This could be as a result of corrupt data or errors

# %%
# To get a better understanding of the data
data["Category"].unique()
# Out:
# array([nan, 'jewelry.pendant', 'jewelry.necklace', 'jewelry.earring',
#        'jewelry.ring', 'jewelry.brooch', 'jewelry.bracelet',
#        'electronics.clocks', 'jewelry.souvenir', '230.12', '202.36',
#        '1098.03', '321.78', '1128.62', '81.27', '34.25', '582.16',
#        '227.37', '234.22', '150.55', '131.82', '2123.15', '109.45',
#        '49.22', '472.47', '205.38', '2746.44', '51.08', '231.12', '76.97',
#        '3054.73', '184.9', '380.1', '357.49', '15.47', '135.33', '719.75',
#        '93.01', '177.95', 'jewelry.stud', '102.1', '595.75', '469.56',
#        '427.07', '53.62', '77.53', '1469.18', '355.27', '184.89',
#        '154.66', '300.58', '83.73', '271.19', '3294.21', '278.04',
#        '3626.26', '126.03', '283.52', '114.38', '89.04', '8.22', '124.88',
#        '89.73', '171.23', '136.93', '19.04', '158.77', '187.1', '151.92',
#        '1845.89', '87.23', '248.58', '596.48', '208.88', '193.11',
#        '169.84', '1447.68', '45.07', '136.85', '282.05', '61.51',
#        '210.21', '137.12', '147.81', '419.45', '825.27', '300.16',
#        '541.78', '308.74', '766.85', '410.82', '101.23', '2.88',
#        '1356.16', '13.42', '35.21', '134.79', '626.58', '13.7', '108.53',
#        '119.01', '7.4', '4.79', '153.97', '482.47', '427.36', '289.18',
#        '25.48', '1858.49', '21.7', '11.77', '198.89', '17.51', '574.66',
#        '1319.93', '393.05', '358.22', '2282.19', '114.93', '371.23',
#        '63.56', '88.77', '133.7', '117.81', '166.03', '130.41', '195.75',
#        '104.79', '228.59', '1686.93', '65.89', '242.19', '252.47',
#        '210.41', '363.42', '149.04', '157.95', '176.3', '160.96', '316.3',
#        '258.77', '268.36', '838.9', '250.96', '832.01', '312.33',
#        '318.71', '323.6', '205.34', '608.22', '343.84', '598.22',
#        '508.08', '245.67', '338.36', '75.21', '573.81', '691.51',
#        '476.68', '247.68', '286.71', '863.67', '236.58', '644.66',
#        '40.82', '1376.99', '1.23', '621.23', '3454.79', '65.62', '59.73',
#        '571.3', '70.96', '271.26', '958.84', '527.26', '271.16', '284.66',
#        '261.64', '493.01', '35.48', '446.16', '526.41', '2517.08',
#        '331.51', '312.88', '148.63', '451.21', '369.82', '537.4',
#        '231.51', '316.34', '451.1', '283.49', '787.67', '131.92',
#        '495.48', '5.48', '186.03', '484.49', '331.23', '133.85', '323.7',
#        '2635.07', '297.22', '0', '259.58', '108.33', '4876.49', '308.08',
#        '190.27', '916.44', '132.53', '1829.37', '2208.9', '75.76',
#        '278.01', '662.3', '253.77'], dtype=object)

# %%
# Extract the actual categories from the data
categories = data["Category"].unique().tolist()
categories = [c for c in categories if isinstance(c, str) and "jewelry" in c]

# %%
categories
# Out:
# ['jewelry.pendant',
#  'jewelry.necklace',
#  'jewelry.earring',
#  'jewelry.ring',
#  'jewelry.brooch',
#  'jewelry.bracelet',
#  'jewelry.souvenir',
#  'jewelry.stud']

# %%
# pick out authentic data based on categories
real_categories = data.loc[data["Category"].isin(categories)]

# %%
# percentage of the missing values
100*data.isnull().sum()/len(data)
# Out:
# Order_Datetime     0.000000
# Order_ID           0.000000
# Product_id         0.000000
# SKU_Quantity       0.000000
# Category_ID        5.580231
# Category          10.356584
# Brand_ID           4.989052
# Price_USD          5.580231
# User_ID            5.580231
# Target_Gender     50.221041
# Main_Color         7.986654
# Main_Metal         5.694922
# Main_Gem          35.510374
# dtype: float64

# %%
# percentage of missing values
100*real_categories.isnull().sum()/len(real_categories)
# Out:
# Order_Datetime     0.000000
# Order_ID           0.000000
# Product_id         0.000000
# SKU_Quantity       0.000000
# Category_ID        0.000000
# Category           0.000000
# Brand_ID           4.309081
# Price_USD          0.000000
# User_ID            0.000000
# Target_Gender     44.842029
# Main_Color         2.656044
# Main_Metal         0.110617
# Main_Gem          24.232519
# dtype: float64

# %%
# Visualize Jewelry categories
subdata = real_categories["Category"].value_counts()

jewelry_categories, counts = subdata.index.tolist(), subdata.values.tolist()

plt.figure(figsize=(12, 8))

plt.pie(x = counts, labels = jewelry_categories, autopct=lambda p:f'{p:.2f}%')

plt.show(); plt.close()

# %%
# While doing univariate analysis of numerical variables we want to study their central tendency and dispersion.
# Let us write a function that will help us create boxplot and histogram for any input numerical variables.
# This function takes the numerical column as the input and retrurns the boxplots and histograms for the variable.
# Let see if this help us write faster and clearer code.

def histogram_boxplot(feature, figsize=(25,15), bins = None):
    """ Boxplot and histogram combined
    feature: 1-d feature array
    figsize: size of fig (default (20,12))
    bins: number of bins (default None / auto)
    """
    f2, (ax_box2, ax_hist2) = plt.subplots(nrows = 2, # Number of rows of the subplot grids=2
                                          sharex = True, # x-axis will be shared among all subplots
                                          gridspec_kw = {"height_ratios": (.25, .75)},
                                          figsize = figsize
                                          )# creating the 2 subplots
    sns.boxplot(x=feature, ax=ax_box2, showmeans=True, color='violet') # boxplot will be created and a star will indicate the mean of the column
    sns.histplot(x=feature, kde=F, ax=ax_hist2, bins=bins, palette="winter") if bins else sns.histplot(x=feature, kde=False, ax=ax_hist2)# for histogram
    ax_hist2.axvline(np.mean(feature), color='green', linestyle='--')# Add mean to the histogram
    ax_hist2.axvline(np.median(feature), color='black', linestyle='-') #Add median to the histogram

# %%
# check for outliers
histogram_boxplot(data['Price_USD'])

# %% [markdown]
# ### Observation
# The outliers in the "Price_USD" indicate incorrect data entries also it could represent rare, customized or high value pieces

# %% [markdown]
# ### Bivariate

# %%
# Jewelry category by Gender
plt. figure(figsize=(12,8))

sns.countplot(data = real_categories, x = "Category", hue ="Target_Gender")

plt.xlabel("Jewelry categories by gender")
plt.ylabel("Frequency")

plt.show();plt.close()

# %% [markdown]
# ### Observation
# The Rings and earrings are more frequent with women, this aligns with traditional jewelry trends

# %%
# Jewelry category by Gender
plt. figure(figsize=(12,8))

sns.countplot(data = real_categories, x = "Category", hue ="Main_Metal")

plt.xlabel("Jewelry categories by Mian_Metal")
plt.ylabel("Frequency")

plt.show();plt.close()

# %% [markdown]
# ### Observation
# The following jewelry in the other earring, ring pendant are most popular amongst male and female while the Brooch, souvenir indicate niche market

# %%
# Create subplots
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(25, 10))  # Adjusted figure size

# Data Aggregation for Target_Gender vs. Price_USD
Target_Gender_Price_USD = data.groupby("Target_Gender")["Price_USD"].count().reset_index()

# Plot Target_Gender vs. Price_USD
sns.barplot(x="Target_Gender", y="Price_USD", data=Target_Gender_Price_USD, ax=axs[0])
axs[0].set_title("Target_Gender vs Price_USD")

# Data Aggregation for Brand_ID vs. Price_USD
Main_Color_Price_USD = data.groupby("Main_Color")["Price_USD"].count().reset_index()

# Plot Brand_ID vs. Price_USD
sns.barplot(x="Main_Color", y="Price_USD", data=Main_Color_Price_USD, ax=axs[1])
axs[1].set_title("Main_Color vs Price_USD")

# Show plots
plt.show()

# %% [markdown]
# ### Observation
# It seems more jewelry items are targeted towards the female than the male.Also it means more jewelry items are available and sold in Red.

# %%
# Create subplots
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(25, 10))  # Adjusted figure size

# Data Aggregation for Target_Gender vs. Main_Metal
Target_Gender_Main_Metal = data.groupby("Target_Gender")["Main_Metal"].count().reset_index()

# Plot Target_Gender vs. Main_Metal
sns.barplot(x="Target_Gender", y="Main_Metal", data=Target_Gender_Main_Metal, ax=axs[0])
axs[0].set_title("Target_Gender vs Main_Metal")

# Data Aggregation for Main_Metal vs. Main_Color
Main_Metal_Main_Color = data.groupby("Main_Metal")["Main_Color"].count().reset_index()

# Plot Main_Metal vs. Main_Color
sns.barplot(x="Main_Metal", y="Main_Color", data=Main_Metal_Main_Color, ax=axs[1])
axs[1].set_title("Main_Metal vs Main_Color")

# Show plots
plt.show()

# %% [markdown]
# ### Observation
# The female purchased more accross the various metal while in column 2 the gold has the more colors than the other metals.Both visualization indicate that the Gold is the most used metal for women

# %% [markdown]
# ### Multivariate

# %%
plt.figure(figsize=(20,5))
sns.barplot(x='Main_Metal', y='Price_USD', data=data, hue='Target_Gender')
# Out:
# <Axes: xlabel='Main_Metal', ylabel='Price_USD'>

# %% [markdown]
# ### Observation
# The male Gender seems to purchase the Gold and silver(Main_Metal) more than the female.Emphasies should be placed on making the distribution betwen Male and Female even

# %%
plt.figure(figsize=(20,5))
sns.barplot(x='Main_Color', y='Price_USD', data=data, hue='Target_Gender')
# Out:
# <Axes: xlabel='Main_Color', ylabel='Price_USD'>

# %% [markdown]
# ### Observation
# The Female Gender prefered the yellow  than the rest colors hence thew price was significantly higher than the others

# %%
plt.figure(figsize=(20,5))
sns.barplot(x='Main_Color', y='Price_USD', data=data, hue='Main_Metal')
# Out:
# <Axes: xlabel='Main_Color', ylabel='Price_USD'>

# %% [markdown]
# ### Observation
# The price of the platinum which indicate premium pricing while the price of Gold is higher than silver and indication of traditional metal value

# %%
plt.figure(figsize=(20,5))
sns.barplot(x='Main_Metal', y='Price_USD', data=data, hue='Main_Color')
# Out:
# <Axes: xlabel='Main_Metal', ylabel='Price_USD'>

# %% [markdown]
# ### Obersation
# Gold has four different colors meaning there are various options for gold than the rest Metals. Obvously more money to be made from the sales of Gold.The colors of the gold are linked to high prices.The Rare colors (black, blue) may indicate designer or specialty jewelry.

# %%
plt.figure(figsize=(20,15))
sns.barplot(x='Main_Gem', y='Price_USD', data=data, hue='Main_Metal')
# Out:
# <Axes: xlabel='Main_Gem', ylabel='Price_USD'>

# %%
plt.figure(figsize=(20,15))
sns.barplot(x='Main_Metal', y='Price_USD', data=data, hue='Main_Gem')
# Out:
# <Axes: xlabel='Main_Metal', ylabel='Price_USD'>

# %% [markdown]
# ### Observation
# Gold Rhodolite gold seems to be the most purchased.

# %%
# Encode jewelry categories
encoded, category_code = pd.factorize(real_categories["Category"])
real_categories.loc[:, "Category"] = encoded

# %%
#encode the Gender
encoded, category_code = pd.factorize(real_categories["Target_Gender"])
real_categories.loc[:, "Target_Gender"] = encoded

# %%
# Encode the Gem
encoded, category_code = pd.factorize(real_categories["Main_Gem"])
real_categories.loc[:, "Main_Gem"] = encoded

# %%
# Encode the color
encoded, category_code = pd.factorize(real_categories["Main_Color"])
real_categories.loc[:, "Main_Color"] = encoded

# %%
# Encode the Metal
encoded, category_code = pd.factorize(real_categories["Main_Metal"])
real_categories.loc[:, "Main_Metal"] = encoded

# %%
real_categories
# Out:
#                 Order_Datetime      Order_ID    Product_id  SKU_Quantity  \
# 1      2018-12-02 13:53:42 UTC  1.925510e+18  1.842210e+18             1
# 2      2018-12-02 17:44:02 UTC  1.925630e+18  1.835570e+18             1
# 3      2018-12-02 21:30:19 UTC  1.925740e+18  1.873940e+18             1
# 4      2018-12-02 22:09:34 UTC  1.925760e+18  1.835570e+18             1
# 5      2018-12-02 22:09:34 UTC  1.925760e+18  1.600020e+18             1
# ...                        ...           ...           ...           ...
# 95900  2021-12-01 09:32:35 UTC  2.719010e+18  1.956660e+18             1
# 95903  2021-12-01 09:37:28 UTC  2.719010e+18  1.956660e+18             1
# 95907  2021-12-01 09:52:06 UTC  2.719020e+18  1.956660e+18             1
# 95908  2021-12-01 09:55:35 UTC  2.719020e+18  1.835570e+18             1
# 95909  2021-12-01 09:59:07 UTC  2.719020e+18  1.956660e+18             1
#
#         Category_ID  Category  Brand_ID  Price_USD       User_ID  \
# 1      1.806830e+18         0       1.0      54.66  1.515920e+18
# 2      1.806830e+18         0       0.0      88.90  1.515920e+18
# 3      1.806830e+18         1       0.0     417.67  1.515920e+18
# 4      1.806830e+18         2       1.0     102.27  1.515920e+18
# 5      1.806830e+18         2       0.0     150.55  1.515920e+18
# ...             ...       ...       ...        ...           ...
# 95900  1.806830e+18         3       0.0     145.62  1.515920e+18
# 95903  1.806830e+18         2       0.0     301.23  1.515920e+18
# 95907  1.806830e+18         2       1.0     630.00  1.515920e+18
# 95908  1.806830e+18         2       0.0      83.42  1.515920e+18
# 95909  1.806830e+18         0       1.0      97.12  1.515920e+18
#
#        Target_Gender  Main_Color  Main_Metal  Main_Gem
# 1                  0           0           0         0
# 2                  0           1           0         1
# 3                 -1           1           0         2
# 4                 -1           1           0        -1
# 5                 -1           1           0         1
# ...              ...         ...         ...       ...
# 95900             -1           1           0        -1
# 95903             -1           1           0         2
# 95907              0           0           0         1
# 95908             -1           0           0         3
# 95909             -1           1           0        -1
#
# [80458 rows x 13 columns]

# %%
real_categories.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80458 entries, 1 to 95909
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order_Datetime  80458 non-null  object
#  1   Order_ID        80458 non-null  float64
#  2   Product_id      80458 non-null  float64
#  3   SKU_Quantity    80458 non-null  int64
#  4   Category_ID     80458 non-null  float64
#  5   Category        80458 non-null  int64
#  6   Brand_ID        76991 non-null  float64
#  7   Price_USD       80458 non-null  float64
#  8   User_ID         80458 non-null  float64
#  9   Target_Gender   80458 non-null  int64
#  10  Main_Color      80458 non-null  int64
#  11  Main_Metal      80458 non-null  int64
#  12  Main_Gem        80458 non-null  int64
# dtypes: float64(6), int64(6), object(1)
# memory usage: 8.6+ MB

# %%
# feature correlation
correlations =real_categories.drop(labels = ["Order_Datetime", "User_ID", "Order_ID", "Product_id"], axis=1).corr(method="spearman")

# %%
correlations
# Out:
#                SKU_Quantity  Category_ID  Category  Brand_ID  Price_USD  \
# SKU_Quantity            NaN          NaN       NaN       NaN        NaN
# Category_ID             NaN     1.000000  0.022894 -0.012950   0.027919
# Category                NaN     0.022894  1.000000 -0.111680   0.267257
# Brand_ID                NaN    -0.012950 -0.111680  1.000000  -0.018428
# Price_USD               NaN     0.027919  0.267257 -0.018428   1.000000
# Target_Gender           NaN     0.040773 -0.124101  0.623701   0.049532
# Main_Color              NaN     0.051492 -0.059402  0.100816   0.013177
# Main_Metal              NaN     0.185724  0.105056  0.003835  -0.173050
# Main_Gem                NaN     0.035895 -0.082944  0.076277  -0.006630
#
#                Target_Gender  Main_Color  Main_Metal  Main_Gem
# SKU_Quantity             NaN         NaN         NaN       NaN
# Category_ID         0.040773    0.051492    0.185724  0.035895
# Category           -0.124101   -0.059402    0.105056 -0.082944
# Brand_ID            0.623701    0.100816    0.003835  0.076277
# Price_USD           0.049532    0.013177   -0.173050 -0.006630
# Target_Gender       1.000000    0.056950   -0.046436  0.166125
# Main_Color          0.056950    1.000000   -0.238080  0.136232
# Main_Metal         -0.046436   -0.238080    1.000000 -0.055603
# Main_Gem            0.166125    0.136232   -0.055603  1.000000

# %%
# correlation heatmap
plt.figure(figsize=(10, 10))

sns.heatmap(correlations, annot = True,center = .3)

plt.show(); plt.close()

# %%
# setting the limits
upper = 1
lower =.2

# %%
#explicitly obtain correlation features
correlated_columns = {
    column: correlations[(correlations[column] >lower) & (upper >correlations[column])].index.tolist()
    for column in correlations.columns
}

# %%
correlated_columns
# Out:
# {'SKU_Quantity': [],
#  'Category_ID': [],
#  'Category': ['Price_USD'],
#  'Brand_ID': ['Target_Gender'],
#  'Price_USD': ['Category'],
#  'Target_Gender': ['Brand_ID'],
#  'Main_Color': [],
#  'Main_Metal': [],
#  'Main_Gem': []}

# %% [markdown]
# ### Data implications
# #### Findings from the data:
# #### 1.Missing values:There were alot of missing values from most of the columns. This can be fixed by data imputation
# #### 2. There were about 2955 duplicated values
# #### 3. Data corruption: some variables (e.g. jewelry_category) contain corrupt values
# #### 4. Target skew:The target variable is highly right skewed. This can present an issue during traing
# #### 5.Correlations: for the most part, the features have low multicolinearity

# %% [markdown]
# ### Data preparation
# ### Based on the data implication the following steps will be experimented upon for the data preparation stage
# 1. missing values:The missing value will be treated via an algorithmic method. SimpleImputer.
#
# 2. Feature Encoding:The categorical features will be encoded.
#
# 3. Target skew: The Target variable is strongly right_skewed
#
# 4.Redundant features: certain feature will be eliminated

# %%
# columns to eliminate
columns_to_eliminate = [
    "SKU_Quantity",
    "Order_ID",
    "Product_id",
    "User_ID",
    "Category_ID"
]

# %%
# Elimate used features
data.drop(labels = columns_to_eliminate, axis = 1, inplace = True)

# %%
data.shape
# Out:
# (95910, 8)

# %%
data.drop(labels = ["Order_Datetime"], axis = 1, inplace = True)

# %%
data.head()
# Out:
#            Category  Brand_ID  Price_USD Target_Gender Main_Color Main_Metal  \
# 0               NaN       NaN     212.14           NaN     yellow       gold
# 1   jewelry.pendant       1.0      54.66             f      white       gold
# 2   jewelry.pendant       0.0      88.90             f        red       gold
# 3  jewelry.necklace       0.0     417.67           NaN        red       gold
# 4   jewelry.earring       1.0     102.27           NaN        red       gold
#
#    Main_Gem
# 0       NaN
# 1  sapphire
# 2   diamond
# 3  amethyst
# 4       NaN

# %%
# Eliminate the unrealistic categories
data = data.loc[data["Category"].isin(categories), :]

# %%
data.shape
# Out:
# (80458, 7)

# %%
from sklearn.model_selection import train_test_split

# %%
# Separate features from labels
X, y = data.drop(labels = ["Price_USD"], axis =1), data["Price_USD"]

# %%
# Create test and train split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = .1)

# %%
X_train
# Out:
#                Category  Brand_ID Target_Gender Main_Color Main_Metal Main_Gem
# 17484   jewelry.earring       1.0             f        NaN     silver   fianit
# 450        jewelry.ring       0.0             f        red       gold   fianit
# 26878   jewelry.pendant       2.0             f        red       gold  diamond
# 80289      jewelry.ring       0.0           NaN        red       gold  diamond
# 83783   jewelry.pendant       1.0             f        red       gold   garnet
# ...                 ...       ...           ...        ...        ...      ...
# 516     jewelry.pendant       1.0             f        red       gold   fianit
# 13171      jewelry.ring       2.0             f        red       gold  diamond
# 71498  jewelry.bracelet       1.0             f        red       gold    pearl
# 87786      jewelry.ring       0.0           NaN        red       gold      NaN
# 37238   jewelry.earring       0.0           NaN        red       gold   fianit
#
# [72412 rows x 6 columns]

# %%
y_train
# Out:
# 17484     21.78
# 450      347.81
# 26878    410.82
# 80289    534.11
# 83783     88.90
#           ...
# 516       51.49
# 13171    356.03
# 71498    157.40
# 87786    194.73
# 37238     86.16
# Name: Price_USD, Length: 72412, dtype: float64

# %% [markdown]
# ### Data Modelling

# %% [markdown]
# 1. Linear Regression,
# 2. Random Forest
# 3. Ada Boosting (AdaBoost) and
# 4. Catboost

# %% [markdown]
# ### 1. Encode categorical features
# ### 2. Account for target skew
# ### 3. Fix missing values

# %%
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder, OneHotEncoder
from sklearn.compose import TransformedTargetRegressor, ColumnTransformer
from sklearn.impute import SimpleImputer

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import AdaBoostRegressor, ExtraTreesRegressor
from catboost import CatBoostRegressor
from sklearn.pipeline import Pipeline

# %%
# customize the pipeline
def generate_pipeline(model, column_indices, categorical_indices, fill_missing = True, one_hot = True, label_encode = False):
    first_transformer = ColumnTransformer(
    transformers = [
        ("imputer", SimpleImputer(strategy = "most_frequent"), column_indices)
    ],
    remainder = "passthrough",
    sparse_threshold = 0.
   )
    
    second_transformer = ColumnTransformer(
         transformers = [
             ("one_hot", OneHotEncoder(), categorical_indices)
         ],
         remainder = "passthrough",
         sparse_threshold = 0.
    )
    third_transformer = ColumnTransformer(
        transformers = [
            ("ordinal", OrdinalEncoder(), categorical_indices)
        ],
        remainder = "passthrough",
        sparse_threshold = 0.
    )
    
    steps = []
    
    if fill_missing:
        steps.append(("impute", first_transformer))
        
    if label_encode:
        steps.append(("second", third_transformer))
    if one_hot:
        steps.append(("second", second_transformer))
    steps.append(("model", model))
    model_pipe = Pipeline(steps = steps)
    return model_pipe

# %%
X.head()
# Out:
#            Category  Brand_ID Target_Gender Main_Color Main_Metal  Main_Gem
# 1   jewelry.pendant       1.0             f      white       gold  sapphire
# 2   jewelry.pendant       0.0             f        red       gold   diamond
# 3  jewelry.necklace       0.0           NaN        red       gold  amethyst
# 4   jewelry.earring       1.0           NaN        red       gold       NaN
# 5   jewelry.earring       0.0           NaN        red       gold   diamond

# %%
# Generate indices
columns = X.columns.tolist()

column_indices = [columns.index(c) for c in columns]
categorical_features = [c for c in columns if c not in ["Brand_ID"]]
categorical_indices = [columns.index(c) for c in categorical_features]  # Fixed

# %%
categorical_indices
# Out:
# [0, 2, 3, 4, 5]

# %%
# CatBoost pipeline
cat_pipe = generate_pipeline(
    CatBoostRegressor(loss_function ="RMSE", iterations = 10000, learning_rate = 0.1, one_hot_max_size = 2),
    column_indices,
    categorical_indices,
    fill_missing = False, one_hot = False, label_encode = True
)

# %%
# LR pipeline
lin_pipe = generate_pipeline(
    LinearRegression(),
    column_indices,
    categorical_indices,
    fill_missing = True, one_hot = True, label_encode = False
)

# %%
# AdaBoost pipeline

ada_pipe = generate_pipeline(
    AdaBoostRegressor(loss = "exponential", n_estimators = 1000, learning_rate=.01),
    column_indices,
    categorical_indices,
    fill_missing = True, one_hot = True, label_encode = False
)

# %%
# ExtraTreeRegressor pipeline

ada_pipe = generate_pipeline(
    ExtraTreesRegressor(criterion = "friedman_mse", n_estimators = 1000, bootstrap=True),
    column_indices,
    categorical_indices,
    fill_missing = True, one_hot = True, label_encode = False
)

# %%
from sklearn.preprocessing import PowerTransformer
# Define the base regressor (ExtraTreesRegressor)
extra_pipe = ExtraTreesRegressor(n_estimators=100)

# %%
# Transform targets
cat_pipe = TransformedTargetRegressor(regressor = cat_pipe, transformer = PowerTransformer(method ="box-cox"))
ada_pipe = TransformedTargetRegressor(regressor = ada_pipe, transformer = PowerTransformer(method ="box-cox"))
lin_pipe = TransformedTargetRegressor(regressor = lin_pipe, transformer = PowerTransformer(method ="box-cox"))
extra_pipe = TransformedTargetRegressor(regressor = extra_pipe, transformer = PowerTransformer(method ="box-cox"))

# %%
# Fit the model for catBoost
cat_pipe.fit(X_train, y_train)  # Should work no
# Out:
# 0:	learn: 0.9626268	total: 187ms	remaining: 31m 14s
# 1:	learn: 0.9242325	total: 205ms	remaining: 17m 5s
# 2:	learn: 0.8972947	total: 221ms	remaining: 12m 16s
# 3:	learn: 0.8696689	total: 238ms	remaining: 9m 56s
# 4:	learn: 0.8497408	total: 256ms	remaining: 8m 30s
# 5:	learn: 0.8335732	total: 273ms	remaining: 7m 35s
# 6:	learn: 0.8147344	total: 290ms	remaining: 6m 54s
# 7:	learn: 0.7996428	total: 307ms	remaining: 6m 23s
# 8:	learn: 0.7894466	total: 324ms	remaining: 5m 59s
# 9:	learn: 0.7795348	total: 340ms	remaining: 5m 40s
# 10:	learn: 0.7690493	total: 358ms	remaining: 5m 25s
# 11:	learn: 0.7610844	total: 375ms	remaining: 5m 11s
# 12:	learn: 0.7543763	total: 392ms	remaining: 5m 1s
# 13:	learn: 0.7489246	total: 410ms	remaining: 4m 52s
# 14:	learn: 0.7414105	total: 427ms	remaining: 4m 44s
# 15:	learn: 0.7373011	total: 446ms	remaining: 4m 38s
# 16:	learn: 0.7305024	total: 462ms	remaining: 4m 31s
# 17:	learn: 0.7271150	total: 479ms	remaining: 4m 25s
# 18:	learn: 0.7234739	total: 495ms	remaining: 4m 19s
# 19:	learn: 0.7184960	total: 512ms	remaining: 4m 15s
# 20:	learn: 0.7158247	total: 528ms	remaining: 4m 11s
# 21:	learn: 0.7112868	total: 546ms	remaining: 4m 7s
# 22:	learn: 0.7095749	total: 564ms	remaining: 4m 4s
# 23:	learn: 0.7059224	total: 583ms	remaining: 4m 2s
# 24:	learn: 0.7043995	total: 600ms	remaining: 3m 59s
# 25:	learn: 0.7007022	total: 618ms	remaining: 3m 57s
# 26:	learn: 0.6979971	total: 636ms	remaining: 3m 54s
# 27:	learn: 0.6958228	total: 653ms	remaining: 3m 52s
# 28:	learn: 0.6932174	total: 672ms	remaining: 3m 50s
# 29:	learn: 0.6916588	total: 690ms	remaining: 3m 49s
# 30:	learn: 0.6900651	total: 709ms	remaining: 3m 47s
# 31:	learn: 0.6889596	total: 726ms	remaining: 3m 46s
# 32:	learn: 0.6873978	total: 744ms	remaining: 3m 44s
# 33:	learn: 0.6863352	total: 762ms	remaining: 3m 43s
# 34:	learn: 0.6846706	total: 781ms	remaining: 3m 42s
# 35:	learn: 0.6840630	total: 797ms	remaining: 3m 40s
# 36:	learn: 0.6827690	total: 814ms	remaining: 3m 39s
# 37:	learn: 0.6820410	total: 829ms	remaining: 3m 37s
# 38:	learn: 0.6809901	total: 845ms	remaining: 3m 35s
# 39:	learn: 0.6802198	total: 861ms	remaining: 3m 34s
# 40:	learn: 0.6796100	total: 877ms	remaining: 3m 33s
# 41:	learn: 0.6791046	total: 893ms	remaining: 3m 31s
# 42:	learn: 0.6782485	total: 910ms	remaining: 3m 30s
# 43:	learn: 0.6776502	total: 927ms	remaining: 3m 29s
# 44:	learn: 0.6771342	total: 943ms	remaining: 3m 28s
# 45:	learn: 0.6757972	total: 961ms	remaining: 3m 27s
# 46:	learn: 0.6750059	total: 978ms	remaining: 3m 27s
# 47:	learn: 0.6743876	total: 996ms	remaining: 3m 26s
# 48:	learn: 0.6734105	total: 1.01s	remaining: 3m 25s
# 49:	learn: 0.6732372	total: 1.03s	remaining: 3m 24s
# 50:	learn: 0.6727305	total: 1.04s	remaining: 3m 23s
# 51:	learn: 0.6720351	total: 1.06s	remaining: 3m 22s
# 52:	learn: 0.6711538	total: 1.07s	remaining: 3m 21s
# 53:	learn: 0.6705885	total: 1.09s	remaining: 3m 20s
# 54:	learn: 0.6701461	total: 1.11s	remaining: 3m 20s
# 55:	learn: 0.6699653	total: 1.12s	remaining: 3m 19s
# 56:	learn: 0.6696649	total: 1.14s	remaining: 3m 18s
# 57:	learn: 0.6687432	total: 1.16s	remaining: 3m 18s
# 58:	learn: 0.6682674	total: 1.18s	remaining: 3m 18s
# 59:	learn: 0.6671419	total: 1.2s	remaining: 3m 18s
# 60:	learn: 0.6666874	total: 1.21s	remaining: 3m 17s
# 61:	learn: 0.6663964	total: 1.23s	remaining: 3m 17s
# 62:	learn: 0.6662238	total: 1.25s	remaining: 3m 16s
# 63:	learn: 0.6660499	total: 1.26s	remaining: 3m 15s
# 64:	learn: 0.6650329	total: 1.28s	remaining: 3m 15s
# 65:	learn: 0.6641625	total: 1.29s	remaining: 3m 14s
# 66:	learn: 0.6640237	total: 1.31s	remaining: 3m 14s
# 67:	learn: 0.6633210	total: 1.32s	remaining: 3m 13s
# 68:	learn: 0.6628561	total: 1.34s	remaining: 3m 12s
# 69:	learn: 0.6625168	total: 1.35s	remaining: 3m 11s
# 70:	learn: 0.6624011	total: 1.37s	remaining: 3m 11s
# 71:	learn: 0.6620486	total: 1.38s	remaining: 3m 10s
# 72:	learn: 0.6615830	total: 1.4s	remaining: 3m 10s
# 73:	learn: 0.6611068	total: 1.42s	remaining: 3m 10s
# 74:	learn: 0.6606040	total: 1.43s	remaining: 3m 9s
# 75:	learn: 0.6602080	total: 1.45s	remaining: 3m 9s
# 76:	learn: 0.6595917	total: 1.47s	remaining: 3m 9s
# 77:	learn: 0.6592104	total: 1.49s	remaining: 3m 9s
# 78:	learn: 0.6587576	total: 1.5s	remaining: 3m 9s
# 79:	learn: 0.6582453	total: 1.52s	remaining: 3m 8s
# 80:	learn: 0.6578049	total: 1.54s	remaining: 3m 8s
# 81:	learn: 0.6576022	total: 1.56s	remaining: 3m 8s
# 82:	learn: 0.6571752	total: 1.58s	remaining: 3m 8s
# 83:	learn: 0.6569945	total: 1.59s	remaining: 3m 8s
# 84:	learn: 0.6568888	total: 1.61s	remaining: 3m 7s
# 85:	learn: 0.6564250	total: 1.63s	remaining: 3m 7s
# 86:	learn: 0.6559915	total: 1.65s	remaining: 3m 7s
# 87:	learn: 0.6558247	total: 1.66s	remaining: 3m 7s
# 88:	learn: 0.6553861	total: 1.68s	remaining: 3m 6s
# 89:	learn: 0.6552674	total: 1.69s	remaining: 3m 6s
# 90:	learn: 0.6546840	total: 1.71s	remaining: 3m 6s
# 91:	learn: 0.6544489	total: 1.73s	remaining: 3m 6s
# 92:	learn: 0.6543474	total: 1.74s	remaining: 3m 5s
# 93:	learn: 0.6542073	total: 1.76s	remaining: 3m 5s
# 94:	learn: 0.6540480	total: 1.78s	remaining: 3m 5s
# 95:	learn: 0.6538898	total: 1.79s	remaining: 3m 5s
# 96:	learn: 0.6537976	total: 1.81s	remaining: 3m 5s
# 97:	learn: 0.6536062	total: 1.83s	remaining: 3m 4s
# 98:	learn: 0.6527899	total: 1.85s	remaining: 3m 4s
# 99:	learn: 0.6527526	total: 1.86s	remaining: 3m 4s
# 100:	learn: 0.6525342	total: 1.88s	remaining: 3m 4s
# 101:	learn: 0.6524351	total: 1.9s	remaining: 3m 4s
# 102:	learn: 0.6522377	total: 1.91s	remaining: 3m 3s
# 103:	learn: 0.6517238	total: 1.93s	remaining: 3m 3s
# 104:	learn: 0.6514349	total: 1.95s	remaining: 3m 3s
# 105:	learn: 0.6513824	total: 1.96s	remaining: 3m 3s
# 106:	learn: 0.6511529	total: 1.98s	remaining: 3m 3s
# 107:	learn: 0.6508226	total: 2s	remaining: 3m 3s
# 108:	learn: 0.6506532	total: 2.02s	remaining: 3m 3s
# 109:	learn: 0.6502796	total: 2.04s	remaining: 3m 3s
# 110:	learn: 0.6499536	total: 2.06s	remaining: 3m 3s
# 111:	learn: 0.6496366	total: 2.07s	remaining: 3m 2s
# 112:	learn: 0.6493843	total: 2.09s	remaining: 3m 2s
# 113:	learn: 0.6492379	total: 2.1s	remaining: 3m 2s
# 114:	learn: 0.6490119	total: 2.12s	remaining: 3m 2s
# 115:	learn: 0.6488168	total: 2.14s	remaining: 3m 2s
# 116:	learn: 0.6487472	total: 2.15s	remaining: 3m 2s
# 117:	learn: 0.6485950	total: 2.17s	remaining: 3m 1s
# 118:	learn: 0.6483791	total: 2.19s	remaining: 3m 1s
# 119:	learn: 0.6480989	total: 2.2s	remaining: 3m 1s
# 120:	learn: 0.6479084	total: 2.22s	remaining: 3m 1s
# 121:	learn: 0.6476916	total: 2.23s	remaining: 3m
# 122:	learn: 0.6475743	total: 2.25s	remaining: 3m
# 123:	learn: 0.6474938	total: 2.27s	remaining: 3m
# 124:	learn: 0.6473698	total: 2.28s	remaining: 3m
# 125:	learn: 0.6471521	total: 2.3s	remaining: 3m
# 126:	learn: 0.6470503	total: 2.31s	remaining: 2m 59s
# 127:	learn: 0.6467327	total: 2.33s	remaining: 2m 59s
# 128:	learn: 0.6466241	total: 2.35s	remaining: 2m 59s
# 129:	learn: 0.6465116	total: 2.36s	remaining: 2m 59s
# 130:	learn: 0.6463068	total: 2.38s	remaining: 2m 59s
# 131:	learn: 0.6462278	total: 2.4s	remaining: 2m 59s
# 132:	learn: 0.6459632	total: 2.42s	remaining: 2m 59s
# 133:	learn: 0.6456450	total: 2.43s	remaining: 2m 59s
# 134:	learn: 0.6454524	total: 2.45s	remaining: 2m 58s
# 135:	learn: 0.6453408	total: 2.46s	remaining: 2m 58s
# 136:	learn: 0.6452603	total: 2.48s	remaining: 2m 58s
# 137:	learn: 0.6451924	total: 2.5s	remaining: 2m 58s
# 138:	learn: 0.6451207	total: 2.52s	remaining: 2m 58s
# 139:	learn: 0.6449745	total: 2.53s	remaining: 2m 58s
# 140:	learn: 0.6448562	total: 2.55s	remaining: 2m 58s
# 141:	learn: 0.6447734	total: 2.57s	remaining: 2m 58s
# 142:	learn: 0.6446538	total: 2.58s	remaining: 2m 58s
# 143:	learn: 0.6445507	total: 2.6s	remaining: 2m 58s
# 144:	learn: 0.6443894	total: 2.62s	remaining: 2m 57s
# 145:	learn: 0.6442116	total: 2.63s	remaining: 2m 57s
# 146:	learn: 0.6440543	total: 2.65s	remaining: 2m 57s
# 147:	learn: 0.6439539	total: 2.67s	remaining: 2m 57s
# 148:	learn: 0.6438810	total: 2.68s	remaining: 2m 57s
# 149:	learn: 0.6438021	total: 2.7s	remaining: 2m 57s
# 150:	learn: 0.6436462	total: 2.72s	remaining: 2m 57s
# 151:	learn: 0.6435612	total: 2.73s	remaining: 2m 57s
# 152:	learn: 0.6434653	total: 2.75s	remaining: 2m 57s
# 153:	learn: 0.6433099	total: 2.77s	remaining: 2m 57s
# 154:	learn: 0.6431378	total: 2.79s	remaining: 2m 56s
# 155:	learn: 0.6430041	total: 2.8s	remaining: 2m 56s
# 156:	learn: 0.6428283	total: 2.82s	remaining: 2m 57s
# 157:	learn: 0.6427718	total: 2.84s	remaining: 2m 56s
# 158:	learn: 0.6426496	total: 2.86s	remaining: 2m 56s
# 159:	learn: 0.6425692	total: 2.87s	remaining: 2m 56s
# 160:	learn: 0.6424397	total: 2.89s	remaining: 2m 56s
# 161:	learn: 0.6423024	total: 2.9s	remaining: 2m 56s
# 162:	learn: 0.6421966	total: 2.92s	remaining: 2m 56s
# 163:	learn: 0.6420693	total: 2.94s	remaining: 2m 56s
# 164:	learn: 0.6420141	total: 2.96s	remaining: 2m 56s
# 165:	learn: 0.6419172	total: 2.97s	remaining: 2m 56s
# 166:	learn: 0.6418008	total: 2.99s	remaining: 2m 56s
# 167:	learn: 0.6417187	total: 3.01s	remaining: 2m 55s
# 168:	learn: 0.6416764	total: 3.02s	remaining: 2m 55s
# 169:	learn: 0.6415894	total: 3.04s	remaining: 2m 55s
# 170:	learn: 0.6415218	total: 3.06s	remaining: 2m 55s
# 171:	learn: 0.6414415	total: 3.08s	remaining: 2m 55s
# 172:	learn: 0.6413220	total: 3.09s	remaining: 2m 55s
# 173:	learn: 0.6410958	total: 3.11s	remaining: 2m 55s
# 174:	learn: 0.6410365	total: 3.12s	remaining: 2m 55s
# 175:	learn: 0.6409008	total: 3.14s	remaining: 2m 55s
# 176:	learn: 0.6408476	total: 3.15s	remaining: 2m 55s
# 177:	learn: 0.6407091	total: 3.17s	remaining: 2m 54s
# 178:	learn: 0.6406784	total: 3.19s	remaining: 2m 54s
# 179:	learn: 0.6405033	total: 3.21s	remaining: 2m 54s
# 180:	learn: 0.6403110	total: 3.22s	remaining: 2m 54s
# 181:	learn: 0.6401964	total: 3.24s	remaining: 2m 54s
# 182:	learn: 0.6401595	total: 3.26s	remaining: 2m 54s
# 183:	learn: 0.6400957	total: 3.27s	remaining: 2m 54s
# 184:	learn: 0.6400238	total: 3.29s	remaining: 2m 54s
# 185:	learn: 0.6399367	total: 3.31s	remaining: 2m 54s
# 186:	learn: 0.6397505	total: 3.32s	remaining: 2m 54s
# 187:	learn: 0.6396971	total: 3.34s	remaining: 2m 54s
# 188:	learn: 0.6396013	total: 3.35s	remaining: 2m 54s
# 189:	learn: 0.6395189	total: 3.37s	remaining: 2m 54s
# 190:	learn: 0.6394617	total: 3.39s	remaining: 2m 53s
# 191:	learn: 0.6394316	total: 3.4s	remaining: 2m 53s
# 192:	learn: 0.6394119	total: 3.42s	remaining: 2m 53s
# 193:	learn: 0.6392649	total: 3.43s	remaining: 2m 53s
# 194:	learn: 0.6392067	total: 3.45s	remaining: 2m 53s
# 195:	learn: 0.6391077	total: 3.46s	remaining: 2m 53s
# 196:	learn: 0.6390577	total: 3.48s	remaining: 2m 53s
# 197:	learn: 0.6389099	total: 3.5s	remaining: 2m 53s
# 198:	learn: 0.6388453	total: 3.52s	remaining: 2m 53s
# 199:	learn: 0.6388083	total: 3.53s	remaining: 2m 53s
# 200:	learn: 0.6386429	total: 3.55s	remaining: 2m 53s
# 201:	learn: 0.6385629	total: 3.57s	remaining: 2m 53s
# 202:	learn: 0.6384743	total: 3.59s	remaining: 2m 53s
# 203:	learn: 0.6383795	total: 3.61s	remaining: 2m 53s
# 204:	learn: 0.6383590	total: 3.62s	remaining: 2m 53s
# 205:	learn: 0.6382642	total: 3.64s	remaining: 2m 52s
# 206:	learn: 0.6381859	total: 3.65s	remaining: 2m 52s
# 207:	learn: 0.6380712	total: 3.67s	remaining: 2m 52s
# 208:	learn: 0.6379639	total: 3.69s	remaining: 2m 52s
# 209:	learn: 0.6379201	total: 3.71s	remaining: 2m 52s
# 210:	learn: 0.6378058	total: 3.72s	remaining: 2m 52s
# 211:	learn: 0.6377701	total: 3.74s	remaining: 2m 52s
# 212:	learn: 0.6376642	total: 3.76s	remaining: 2m 52s
# 213:	learn: 0.6376217	total: 3.77s	remaining: 2m 52s
# 214:	learn: 0.6374898	total: 3.79s	remaining: 2m 52s
# 215:	learn: 0.6372551	total: 3.81s	remaining: 2m 52s
# 216:	learn: 0.6371862	total: 3.83s	remaining: 2m 52s
# 217:	learn: 0.6371451	total: 3.85s	remaining: 2m 52s
# 218:	learn: 0.6370276	total: 3.87s	remaining: 2m 52s
# 219:	learn: 0.6369960	total: 3.88s	remaining: 2m 52s
# 220:	learn: 0.6369532	total: 3.9s	remaining: 2m 52s
# 221:	learn: 0.6368770	total: 3.91s	remaining: 2m 52s
# 222:	learn: 0.6367457	total: 3.93s	remaining: 2m 52s
# 223:	learn: 0.6366780	total: 3.95s	remaining: 2m 52s
# 224:	learn: 0.6366610	total: 3.96s	remaining: 2m 52s
# 225:	learn: 0.6365981	total: 3.98s	remaining: 2m 52s
# 226:	learn: 0.6365121	total: 4s	remaining: 2m 52s
# 227:	learn: 0.6363136	total: 4.02s	remaining: 2m 52s
# 228:	learn: 0.6362884	total: 4.03s	remaining: 2m 52s
# 229:	learn: 0.6360055	total: 4.05s	remaining: 2m 52s
# 230:	learn: 0.6358813	total: 4.07s	remaining: 2m 52s
# 231:	learn: 0.6358159	total: 4.08s	remaining: 2m 52s
# 232:	learn: 0.6357519	total: 4.1s	remaining: 2m 51s
# 233:	learn: 0.6355384	total: 4.12s	remaining: 2m 52s
# 234:	learn: 0.6353622	total: 4.14s	remaining: 2m 52s
# 235:	learn: 0.6352888	total: 4.16s	remaining: 2m 51s
# 236:	learn: 0.6350806	total: 4.17s	remaining: 2m 51s
# 237:	learn: 0.6348877	total: 4.19s	remaining: 2m 51s
# 238:	learn: 0.6348537	total: 4.21s	remaining: 2m 51s
# 239:	learn: 0.6347454	total: 4.22s	remaining: 2m 51s
# 240:	learn: 0.6347088	total: 4.24s	remaining: 2m 51s
# 241:	learn: 0.6346724	total: 4.26s	remaining: 2m 51s
# 242:	learn: 0.6345856	total: 4.27s	remaining: 2m 51s
# 243:	learn: 0.6344942	total: 4.29s	remaining: 2m 51s
# 244:	learn: 0.6344229	total: 4.31s	remaining: 2m 51s
# 245:	learn: 0.6343864	total: 4.32s	remaining: 2m 51s
# 246:	learn: 0.6342906	total: 4.34s	remaining: 2m 51s
# 247:	learn: 0.6342527	total: 4.36s	remaining: 2m 51s
# 248:	learn: 0.6342197	total: 4.37s	remaining: 2m 51s
# 249:	learn: 0.6341655	total: 4.39s	remaining: 2m 51s
# 250:	learn: 0.6341154	total: 4.41s	remaining: 2m 51s
# 251:	learn: 0.6338487	total: 4.42s	remaining: 2m 51s
# 252:	learn: 0.6337925	total: 4.44s	remaining: 2m 51s
# 253:	learn: 0.6337369	total: 4.46s	remaining: 2m 51s
# 254:	learn: 0.6337182	total: 4.47s	remaining: 2m 50s
# 255:	learn: 0.6336894	total: 4.49s	remaining: 2m 50s
# 256:	learn: 0.6336069	total: 4.51s	remaining: 2m 50s
# 257:	learn: 0.6335256	total: 4.52s	remaining: 2m 50s
# 258:	learn: 0.6334531	total: 4.54s	remaining: 2m 50s
# 259:	learn: 0.6334135	total: 4.55s	remaining: 2m 50s
# 260:	learn: 0.6333358	total: 4.57s	remaining: 2m 50s
# 261:	learn: 0.6333098	total: 4.59s	remaining: 2m 50s
# 262:	learn: 0.6332674	total: 4.6s	remaining: 2m 50s
# 263:	learn: 0.6330930	total: 4.62s	remaining: 2m 50s
# 264:	learn: 0.6330488	total: 4.64s	remaining: 2m 50s
# 265:	learn: 0.6330096	total: 4.65s	remaining: 2m 50s
# 266:	learn: 0.6329927	total: 4.67s	remaining: 2m 50s
# 267:	learn: 0.6329307	total: 4.69s	remaining: 2m 50s
# 268:	learn: 0.6328591	total: 4.71s	remaining: 2m 50s
# 269:	learn: 0.6328510	total: 4.72s	remaining: 2m 50s
# 270:	learn: 0.6328361	total: 4.74s	remaining: 2m 50s
# 271:	learn: 0.6327846	total: 4.75s	remaining: 2m 49s
# 272:	learn: 0.6327400	total: 4.77s	remaining: 2m 49s
# 273:	learn: 0.6327174	total: 4.78s	remaining: 2m 49s
# 274:	learn: 0.6325810	total: 4.8s	remaining: 2m 49s
# 275:	learn: 0.6323688	total: 4.82s	remaining: 2m 49s
# 276:	learn: 0.6323332	total: 4.83s	remaining: 2m 49s
# 277:	learn: 0.6322620	total: 4.85s	remaining: 2m 49s
# 278:	learn: 0.6321941	total: 4.87s	remaining: 2m 49s
# 279:	learn: 0.6320048	total: 4.88s	remaining: 2m 49s
# 280:	learn: 0.6318311	total: 4.9s	remaining: 2m 49s
# 281:	learn: 0.6317790	total: 4.92s	remaining: 2m 49s
# 282:	learn: 0.6316518	total: 4.94s	remaining: 2m 49s
# 283:	learn: 0.6316204	total: 4.95s	remaining: 2m 49s
# 284:	learn: 0.6315857	total: 4.97s	remaining: 2m 49s
# 285:	learn: 0.6314964	total: 4.99s	remaining: 2m 49s
# 286:	learn: 0.6314589	total: 5s	remaining: 2m 49s
# 287:	learn: 0.6314163	total: 5.02s	remaining: 2m 49s
# 288:	learn: 0.6313501	total: 5.04s	remaining: 2m 49s
# 289:	learn: 0.6313303	total: 5.05s	remaining: 2m 49s
# 290:	learn: 0.6312680	total: 5.07s	remaining: 2m 49s
# 291:	learn: 0.6311101	total: 5.09s	remaining: 2m 49s
# 292:	learn: 0.6310659	total: 5.11s	remaining: 2m 49s
# 293:	learn: 0.6309410	total: 5.12s	remaining: 2m 49s
# 294:	learn: 0.6308675	total: 5.14s	remaining: 2m 49s
# 295:	learn: 0.6308225	total: 5.16s	remaining: 2m 49s
# 296:	learn: 0.6307648	total: 5.17s	remaining: 2m 49s
# 297:	learn: 0.6306989	total: 5.19s	remaining: 2m 48s
# 298:	learn: 0.6306742	total: 5.21s	remaining: 2m 48s
# 299:	learn: 0.6306240	total: 5.22s	remaining: 2m 48s
# 300:	learn: 0.6305649	total: 5.24s	remaining: 2m 48s
# 301:	learn: 0.6305029	total: 5.26s	remaining: 2m 48s
# 302:	learn: 0.6304345	total: 5.28s	remaining: 2m 48s
# 303:	learn: 0.6303549	total: 5.3s	remaining: 2m 48s
# 304:	learn: 0.6303367	total: 5.31s	remaining: 2m 48s
# 305:	learn: 0.6302569	total: 5.33s	remaining: 2m 48s
# 306:	learn: 0.6302235	total: 5.35s	remaining: 2m 48s
# 307:	learn: 0.6301876	total: 5.37s	remaining: 2m 48s
# 308:	learn: 0.6301507	total: 5.38s	remaining: 2m 48s
# 309:	learn: 0.6301073	total: 5.4s	remaining: 2m 48s
# 310:	learn: 0.6300647	total: 5.42s	remaining: 2m 48s
# 311:	learn: 0.6300383	total: 5.43s	remaining: 2m 48s
# 312:	learn: 0.6300023	total: 5.45s	remaining: 2m 48s
# 313:	learn: 0.6299322	total: 5.47s	remaining: 2m 48s
# 314:	learn: 0.6298205	total: 5.49s	remaining: 2m 48s
# 315:	learn: 0.6296928	total: 5.51s	remaining: 2m 48s
# 316:	learn: 0.6296174	total: 5.53s	remaining: 2m 48s
# 317:	learn: 0.6294898	total: 5.54s	remaining: 2m 48s
# 318:	learn: 0.6294384	total: 5.56s	remaining: 2m 48s
# 319:	learn: 0.6293881	total: 5.58s	remaining: 2m 48s
# 320:	learn: 0.6293648	total: 5.59s	remaining: 2m 48s
# 321:	learn: 0.6292889	total: 5.61s	remaining: 2m 48s
# 322:	learn: 0.6292227	total: 5.63s	remaining: 2m 48s
# 323:	learn: 0.6291583	total: 5.65s	remaining: 2m 48s
# 324:	learn: 0.6291043	total: 5.66s	remaining: 2m 48s
# 325:	learn: 0.6290798	total: 5.68s	remaining: 2m 48s
# 326:	learn: 0.6290206	total: 5.7s	remaining: 2m 48s
# 327:	learn: 0.6289808	total: 5.71s	remaining: 2m 48s
# 328:	learn: 0.6288767	total: 5.73s	remaining: 2m 48s
# 329:	learn: 0.6288456	total: 5.74s	remaining: 2m 48s
# 330:	learn: 0.6288204	total: 5.76s	remaining: 2m 48s
# 331:	learn: 0.6287749	total: 5.78s	remaining: 2m 48s
# 332:	learn: 0.6287498	total: 5.79s	remaining: 2m 48s
# 333:	learn: 0.6287082	total: 5.81s	remaining: 2m 48s
# 334:	learn: 0.6286905	total: 5.83s	remaining: 2m 48s
# 335:	learn: 0.6285890	total: 5.85s	remaining: 2m 48s
# 336:	learn: 0.6285777	total: 5.86s	remaining: 2m 48s
# 337:	learn: 0.6285563	total: 5.88s	remaining: 2m 48s
# 338:	learn: 0.6285429	total: 5.89s	remaining: 2m 48s
# 339:	learn: 0.6285282	total: 5.91s	remaining: 2m 47s
# 340:	learn: 0.6284762	total: 5.93s	remaining: 2m 47s
# 341:	learn: 0.6283909	total: 5.95s	remaining: 2m 47s
# 342:	learn: 0.6283378	total: 5.96s	remaining: 2m 47s
# 343:	learn: 0.6283205	total: 5.98s	remaining: 2m 47s
# 344:	learn: 0.6282631	total: 6s	remaining: 2m 47s
# 345:	learn: 0.6281701	total: 6.01s	remaining: 2m 47s
# 346:	learn: 0.6281508	total: 6.03s	remaining: 2m 47s
# 347:	learn: 0.6280795	total: 6.05s	remaining: 2m 47s
# 348:	learn: 0.6280425	total: 6.07s	remaining: 2m 47s
# 349:	learn: 0.6280197	total: 6.09s	remaining: 2m 47s
# 350:	learn: 0.6279707	total: 6.11s	remaining: 2m 47s
# 351:	learn: 0.6279640	total: 6.12s	remaining: 2m 47s
# 352:	learn: 0.6279187	total: 6.14s	remaining: 2m 47s
# 353:	learn: 0.6278733	total: 6.16s	remaining: 2m 47s
# 354:	learn: 0.6278360	total: 6.18s	remaining: 2m 47s
# 355:	learn: 0.6278284	total: 6.2s	remaining: 2m 47s
# 356:	learn: 0.6277755	total: 6.21s	remaining: 2m 47s
# 357:	learn: 0.6277620	total: 6.23s	remaining: 2m 47s
# 358:	learn: 0.6276529	total: 6.25s	remaining: 2m 47s
# 359:	learn: 0.6276019	total: 6.26s	remaining: 2m 47s
# 360:	learn: 0.6275599	total: 6.28s	remaining: 2m 47s
# 361:	learn: 0.6274471	total: 6.3s	remaining: 2m 47s
# 362:	learn: 0.6274388	total: 6.32s	remaining: 2m 47s
# 363:	learn: 0.6273776	total: 6.33s	remaining: 2m 47s
# 364:	learn: 0.6273245	total: 6.35s	remaining: 2m 47s
# 365:	learn: 0.6273094	total: 6.37s	remaining: 2m 47s
# 366:	learn: 0.6272783	total: 6.39s	remaining: 2m 47s
# 367:	learn: 0.6272510	total: 6.41s	remaining: 2m 47s
# 368:	learn: 0.6272459	total: 6.42s	remaining: 2m 47s
# 369:	learn: 0.6272097	total: 6.44s	remaining: 2m 47s
# 370:	learn: 0.6272049	total: 6.45s	remaining: 2m 47s
# 371:	learn: 0.6272048	total: 6.46s	remaining: 2m 47s
# 372:	learn: 0.6271927	total: 6.48s	remaining: 2m 47s
# 373:	learn: 0.6271624	total: 6.5s	remaining: 2m 47s
# 374:	learn: 0.6271623	total: 6.5s	remaining: 2m 46s
# 375:	learn: 0.6271623	total: 6.51s	remaining: 2m 46s
# 376:	learn: 0.6270867	total: 6.53s	remaining: 2m 46s
# 377:	learn: 0.6270585	total: 6.54s	remaining: 2m 46s
# 378:	learn: 0.6270499	total: 6.56s	remaining: 2m 46s
# 379:	learn: 0.6270126	total: 6.58s	remaining: 2m 46s
# 380:	learn: 0.6269721	total: 6.6s	remaining: 2m 46s
# 381:	learn: 0.6269720	total: 6.61s	remaining: 2m 46s
# 382:	learn: 0.6269484	total: 6.62s	remaining: 2m 46s
# 383:	learn: 0.6269099	total: 6.64s	remaining: 2m 46s
# 384:	learn: 0.6268796	total: 6.66s	remaining: 2m 46s
# 385:	learn: 0.6268476	total: 6.67s	remaining: 2m 46s
# 386:	learn: 0.6268082	total: 6.69s	remaining: 2m 46s
# 387:	learn: 0.6267993	total: 6.71s	remaining: 2m 46s
# 388:	learn: 0.6267926	total: 6.73s	remaining: 2m 46s
# 389:	learn: 0.6267669	total: 6.74s	remaining: 2m 46s
# 390:	learn: 0.6266879	total: 6.76s	remaining: 2m 46s
# 391:	learn: 0.6266759	total: 6.78s	remaining: 2m 46s
# 392:	learn: 0.6266617	total: 6.79s	remaining: 2m 46s
# 393:	learn: 0.6266522	total: 6.81s	remaining: 2m 46s
# 394:	learn: 0.6265987	total: 6.83s	remaining: 2m 46s
# 395:	learn: 0.6265267	total: 6.84s	remaining: 2m 46s
# 396:	learn: 0.6265054	total: 6.86s	remaining: 2m 46s
# 397:	learn: 0.6264721	total: 6.88s	remaining: 2m 45s
# 398:	learn: 0.6264440	total: 6.9s	remaining: 2m 45s
# 399:	learn: 0.6264067	total: 6.91s	remaining: 2m 45s
# 400:	learn: 0.6264067	total: 6.92s	remaining: 2m 45s
# 401:	learn: 0.6263835	total: 6.94s	remaining: 2m 45s
# 402:	learn: 0.6263705	total: 6.96s	remaining: 2m 45s
# 403:	learn: 0.6263501	total: 6.98s	remaining: 2m 45s
# 404:	learn: 0.6263053	total: 6.99s	remaining: 2m 45s
# 405:	learn: 0.6262855	total: 7.01s	remaining: 2m 45s
# 406:	learn: 0.6262665	total: 7.03s	remaining: 2m 45s
# 407:	learn: 0.6262366	total: 7.04s	remaining: 2m 45s
# 408:	learn: 0.6261925	total: 7.06s	remaining: 2m 45s
# 409:	learn: 0.6260622	total: 7.08s	remaining: 2m 45s
# 410:	learn: 0.6260106	total: 7.1s	remaining: 2m 45s
# 411:	learn: 0.6259942	total: 7.11s	remaining: 2m 45s
# 412:	learn: 0.6259750	total: 7.13s	remaining: 2m 45s
# 413:	learn: 0.6259750	total: 7.14s	remaining: 2m 45s
# 414:	learn: 0.6259750	total: 7.15s	remaining: 2m 45s
# 415:	learn: 0.6259527	total: 7.17s	remaining: 2m 45s
# 416:	learn: 0.6259411	total: 7.18s	remaining: 2m 45s
# 417:	learn: 0.6259063	total: 7.2s	remaining: 2m 45s
# 418:	learn: 0.6258989	total: 7.21s	remaining: 2m 44s
# 419:	learn: 0.6258825	total: 7.23s	remaining: 2m 44s
# 420:	learn: 0.6258202	total: 7.25s	remaining: 2m 44s
# 421:	learn: 0.6257645	total: 7.26s	remaining: 2m 44s
# 422:	learn: 0.6257432	total: 7.28s	remaining: 2m 44s
# 423:	learn: 0.6257374	total: 7.29s	remaining: 2m 44s
# 424:	learn: 0.6257312	total: 7.31s	remaining: 2m 44s
# 425:	learn: 0.6257267	total: 7.33s	remaining: 2m 44s
# 426:	learn: 0.6257136	total: 7.34s	remaining: 2m 44s
# 427:	learn: 0.6256818	total: 7.36s	remaining: 2m 44s
# 428:	learn: 0.6256736	total: 7.37s	remaining: 2m 44s
# 429:	learn: 0.6256514	total: 7.39s	remaining: 2m 44s
# 430:	learn: 0.6256514	total: 7.4s	remaining: 2m 44s
# 431:	learn: 0.6256463	total: 7.41s	remaining: 2m 44s
# 432:	learn: 0.6256067	total: 7.43s	remaining: 2m 44s
# 433:	learn: 0.6255955	total: 7.45s	remaining: 2m 44s
# 434:	learn: 0.6255744	total: 7.46s	remaining: 2m 44s
# 435:	learn: 0.6255650	total: 7.48s	remaining: 2m 44s
# 436:	learn: 0.6255391	total: 7.5s	remaining: 2m 44s
# 437:	learn: 0.6255194	total: 7.51s	remaining: 2m 44s
# 438:	learn: 0.6254956	total: 7.53s	remaining: 2m 44s
# 439:	learn: 0.6253806	total: 7.55s	remaining: 2m 44s
# 440:	learn: 0.6253729	total: 7.57s	remaining: 2m 44s
# 441:	learn: 0.6253558	total: 7.58s	remaining: 2m 43s
# 442:	learn: 0.6253385	total: 7.6s	remaining: 2m 43s
# 443:	learn: 0.6252170	total: 7.62s	remaining: 2m 43s
# 444:	learn: 0.6251984	total: 7.63s	remaining: 2m 43s
# 445:	learn: 0.6251984	total: 7.64s	remaining: 2m 43s
# 446:	learn: 0.6251793	total: 7.66s	remaining: 2m 43s
# 447:	learn: 0.6251054	total: 7.68s	remaining: 2m 43s
# 448:	learn: 0.6251015	total: 7.69s	remaining: 2m 43s
# 449:	learn: 0.6250929	total: 7.71s	remaining: 2m 43s
# 450:	learn: 0.6250425	total: 7.73s	remaining: 2m 43s
# 451:	learn: 0.6250312	total: 7.75s	remaining: 2m 43s
# 452:	learn: 0.6250047	total: 7.76s	remaining: 2m 43s
# 453:	learn: 0.6249912	total: 7.78s	remaining: 2m 43s
# 454:	learn: 0.6249618	total: 7.8s	remaining: 2m 43s
# 455:	learn: 0.6249495	total: 7.81s	remaining: 2m 43s
# 456:	learn: 0.6249274	total: 7.83s	remaining: 2m 43s
# 457:	learn: 0.6248758	total: 7.85s	remaining: 2m 43s
# 458:	learn: 0.6248446	total: 7.86s	remaining: 2m 43s
# 459:	learn: 0.6248278	total: 7.88s	remaining: 2m 43s
# 460:	learn: 0.6248097	total: 7.9s	remaining: 2m 43s
# 461:	learn: 0.6247491	total: 7.91s	remaining: 2m 43s
# 462:	learn: 0.6247285	total: 7.93s	remaining: 2m 43s
# 463:	learn: 0.6246455	total: 7.95s	remaining: 2m 43s
# 464:	learn: 0.6246154	total: 7.96s	remaining: 2m 43s
# 465:	learn: 0.6245645	total: 7.98s	remaining: 2m 43s
# 466:	learn: 0.6245383	total: 8s	remaining: 2m 43s
# 467:	learn: 0.6245020	total: 8.02s	remaining: 2m 43s
# 468:	learn: 0.6244872	total: 8.03s	remaining: 2m 43s
# 469:	learn: 0.6244785	total: 8.05s	remaining: 2m 43s
# 470:	learn: 0.6244128	total: 8.06s	remaining: 2m 43s
# 471:	learn: 0.6243207	total: 8.08s	remaining: 2m 43s
# 472:	learn: 0.6242484	total: 8.1s	remaining: 2m 43s
# 473:	learn: 0.6242287	total: 8.12s	remaining: 2m 43s
# 474:	learn: 0.6242287	total: 8.13s	remaining: 2m 43s
# 475:	learn: 0.6242093	total: 8.15s	remaining: 2m 43s
# 476:	learn: 0.6241966	total: 8.16s	remaining: 2m 43s
# 477:	learn: 0.6241787	total: 8.19s	remaining: 2m 43s
# 478:	learn: 0.6241787	total: 8.2s	remaining: 2m 42s
# 479:	learn: 0.6241636	total: 8.21s	remaining: 2m 42s
# 480:	learn: 0.6241363	total: 8.23s	remaining: 2m 42s
# 481:	learn: 0.6241169	total: 8.24s	remaining: 2m 42s
# 482:	learn: 0.6241040	total: 8.26s	remaining: 2m 42s
# 483:	learn: 0.6240911	total: 8.28s	remaining: 2m 42s
# 484:	learn: 0.6240519	total: 8.3s	remaining: 2m 42s
# 485:	learn: 0.6240492	total: 8.31s	remaining: 2m 42s
# 486:	learn: 0.6240160	total: 8.33s	remaining: 2m 42s
# 487:	learn: 0.6240119	total: 8.34s	remaining: 2m 42s
# 488:	learn: 0.6239987	total: 8.36s	remaining: 2m 42s
# 489:	learn: 0.6239767	total: 8.38s	remaining: 2m 42s
# 490:	learn: 0.6239469	total: 8.39s	remaining: 2m 42s
# 491:	learn: 0.6239310	total: 8.41s	remaining: 2m 42s
# 492:	learn: 0.6239296	total: 8.43s	remaining: 2m 42s
# 493:	learn: 0.6239141	total: 8.45s	remaining: 2m 42s
# 494:	learn: 0.6238843	total: 8.46s	remaining: 2m 42s
# 495:	learn: 0.6238820	total: 8.48s	remaining: 2m 42s
# 496:	learn: 0.6238735	total: 8.49s	remaining: 2m 42s
# 497:	learn: 0.6238518	total: 8.51s	remaining: 2m 42s
# 498:	learn: 0.6238263	total: 8.53s	remaining: 2m 42s
# 499:	learn: 0.6237825	total: 8.54s	remaining: 2m 42s
# 500:	learn: 0.6237825	total: 8.55s	remaining: 2m 42s
# 501:	learn: 0.6237684	total: 8.57s	remaining: 2m 42s
# 502:	learn: 0.6237570	total: 8.59s	remaining: 2m 42s
# 503:	learn: 0.6237570	total: 8.6s	remaining: 2m 41s
# 504:	learn: 0.6237280	total: 8.61s	remaining: 2m 41s
# 505:	learn: 0.6237133	total: 8.63s	remaining: 2m 41s
# 506:	learn: 0.6237024	total: 8.65s	remaining: 2m 41s
# 507:	learn: 0.6236742	total: 8.66s	remaining: 2m 41s
# 508:	learn: 0.6236551	total: 8.68s	remaining: 2m 41s
# 509:	learn: 0.6236436	total: 8.7s	remaining: 2m 41s
# 510:	learn: 0.6236301	total: 8.71s	remaining: 2m 41s
# 511:	learn: 0.6236106	total: 8.73s	remaining: 2m 41s
# 512:	learn: 0.6235692	total: 8.75s	remaining: 2m 41s
# 513:	learn: 0.6235440	total: 8.77s	remaining: 2m 41s
# 514:	learn: 0.6234933	total: 8.79s	remaining: 2m 41s
# 515:	learn: 0.6234721	total: 8.8s	remaining: 2m 41s
# 516:	learn: 0.6234700	total: 8.82s	remaining: 2m 41s
# 517:	learn: 0.6234586	total: 8.84s	remaining: 2m 41s
# 518:	learn: 0.6233977	total: 8.85s	remaining: 2m 41s
# 519:	learn: 0.6233814	total: 8.87s	remaining: 2m 41s
# 520:	learn: 0.6233649	total: 8.89s	remaining: 2m 41s
# 521:	learn: 0.6233120	total: 8.91s	remaining: 2m 41s
# 522:	learn: 0.6232352	total: 8.93s	remaining: 2m 41s
# 523:	learn: 0.6232152	total: 8.94s	remaining: 2m 41s
# 524:	learn: 0.6231902	total: 8.96s	remaining: 2m 41s
# 525:	learn: 0.6231499	total: 8.98s	remaining: 2m 41s
# 526:	learn: 0.6231391	total: 8.99s	remaining: 2m 41s
# 527:	learn: 0.6231296	total: 9.01s	remaining: 2m 41s
# 528:	learn: 0.6231142	total: 9.03s	remaining: 2m 41s
# 529:	learn: 0.6230976	total: 9.05s	remaining: 2m 41s
# 530:	learn: 0.6230732	total: 9.07s	remaining: 2m 41s
# 531:	learn: 0.6230655	total: 9.08s	remaining: 2m 41s
# 532:	learn: 0.6230589	total: 9.1s	remaining: 2m 41s
# 533:	learn: 0.6230214	total: 9.12s	remaining: 2m 41s
# 534:	learn: 0.6229481	total: 9.13s	remaining: 2m 41s
# 535:	learn: 0.6229118	total: 9.15s	remaining: 2m 41s
# 536:	learn: 0.6228577	total: 9.17s	remaining: 2m 41s
# 537:	learn: 0.6228487	total: 9.19s	remaining: 2m 41s
# 538:	learn: 0.6228361	total: 9.2s	remaining: 2m 41s
# 539:	learn: 0.6228315	total: 9.22s	remaining: 2m 41s
# 540:	learn: 0.6228281	total: 9.23s	remaining: 2m 41s
# 541:	learn: 0.6227944	total: 9.25s	remaining: 2m 41s
# 542:	learn: 0.6227765	total: 9.27s	remaining: 2m 41s
# 543:	learn: 0.6227330	total: 9.29s	remaining: 2m 41s
# 544:	learn: 0.6227243	total: 9.3s	remaining: 2m 41s
# 545:	learn: 0.6227030	total: 9.32s	remaining: 2m 41s
# 546:	learn: 0.6226842	total: 9.34s	remaining: 2m 41s
# 547:	learn: 0.6225970	total: 9.36s	remaining: 2m 41s
# 548:	learn: 0.6225739	total: 9.38s	remaining: 2m 41s
# 549:	learn: 0.6225579	total: 9.4s	remaining: 2m 41s
# 550:	learn: 0.6225251	total: 9.41s	remaining: 2m 41s
# 551:	learn: 0.6225070	total: 9.43s	remaining: 2m 41s
# 552:	learn: 0.6224811	total: 9.45s	remaining: 2m 41s
# 553:	learn: 0.6224680	total: 9.46s	remaining: 2m 41s
# 554:	learn: 0.6224583	total: 9.48s	remaining: 2m 41s
# 555:	learn: 0.6224430	total: 9.5s	remaining: 2m 41s
# 556:	learn: 0.6224184	total: 9.51s	remaining: 2m 41s
# 557:	learn: 0.6224060	total: 9.53s	remaining: 2m 41s
# 558:	learn: 0.6223867	total: 9.55s	remaining: 2m 41s
# 559:	learn: 0.6223371	total: 9.56s	remaining: 2m 41s
# 560:	learn: 0.6223288	total: 9.58s	remaining: 2m 41s
# 561:	learn: 0.6223105	total: 9.6s	remaining: 2m 41s
# 562:	learn: 0.6222997	total: 9.62s	remaining: 2m 41s
# 563:	learn: 0.6222950	total: 9.63s	remaining: 2m 41s
# 564:	learn: 0.6222950	total: 9.64s	remaining: 2m 40s
# 565:	learn: 0.6222230	total: 9.65s	remaining: 2m 40s
# 566:	learn: 0.6221969	total: 9.67s	remaining: 2m 40s
# 567:	learn: 0.6221909	total: 9.69s	remaining: 2m 40s
# 568:	learn: 0.6221677	total: 9.7s	remaining: 2m 40s
# 569:	learn: 0.6221422	total: 9.72s	remaining: 2m 40s
# 570:	learn: 0.6221422	total: 9.73s	remaining: 2m 40s
# 571:	learn: 0.6221322	total: 9.75s	remaining: 2m 40s
# 572:	learn: 0.6221156	total: 9.76s	remaining: 2m 40s
# 573:	learn: 0.6220994	total: 9.78s	remaining: 2m 40s
# 574:	learn: 0.6220969	total: 9.8s	remaining: 2m 40s
# 575:	learn: 0.6220653	total: 9.81s	remaining: 2m 40s
# 576:	learn: 0.6220569	total: 9.83s	remaining: 2m 40s
# 577:	learn: 0.6220387	total: 9.85s	remaining: 2m 40s
# 578:	learn: 0.6220372	total: 9.86s	remaining: 2m 40s
# 579:	learn: 0.6220190	total: 9.88s	remaining: 2m 40s
# 580:	learn: 0.6219914	total: 9.9s	remaining: 2m 40s
# 581:	learn: 0.6219780	total: 9.91s	remaining: 2m 40s
# 582:	learn: 0.6219714	total: 9.93s	remaining: 2m 40s
# 583:	learn: 0.6219260	total: 9.95s	remaining: 2m 40s
# 584:	learn: 0.6219168	total: 9.97s	remaining: 2m 40s
# 585:	learn: 0.6218992	total: 9.98s	remaining: 2m 40s
# 586:	learn: 0.6218594	total: 10s	remaining: 2m 40s
# 587:	learn: 0.6218467	total: 10s	remaining: 2m 40s
# 588:	learn: 0.6218394	total: 10s	remaining: 2m 40s
# 589:	learn: 0.6218342	total: 10.1s	remaining: 2m 40s
# 590:	learn: 0.6218271	total: 10.1s	remaining: 2m 40s
# 591:	learn: 0.6218271	total: 10.1s	remaining: 2m 40s
# 592:	learn: 0.6218143	total: 10.1s	remaining: 2m 40s
# 593:	learn: 0.6217983	total: 10.1s	remaining: 2m 40s
# 594:	learn: 0.6217795	total: 10.1s	remaining: 2m 40s
# 595:	learn: 0.6217676	total: 10.2s	remaining: 2m 40s
# 596:	learn: 0.6217369	total: 10.2s	remaining: 2m 40s
# 597:	learn: 0.6217262	total: 10.2s	remaining: 2m 40s
# 598:	learn: 0.6217201	total: 10.2s	remaining: 2m 40s
# 599:	learn: 0.6217063	total: 10.2s	remaining: 2m 40s
# 600:	learn: 0.6217007	total: 10.2s	remaining: 2m 40s
# 601:	learn: 0.6216732	total: 10.3s	remaining: 2m 40s
# 602:	learn: 0.6216225	total: 10.3s	remaining: 2m 40s
# 603:	learn: 0.6215960	total: 10.3s	remaining: 2m 40s
# 604:	learn: 0.6215936	total: 10.3s	remaining: 2m 40s
# 605:	learn: 0.6215795	total: 10.3s	remaining: 2m 40s
# 606:	learn: 0.6215609	total: 10.3s	remaining: 2m 40s
# 607:	learn: 0.6215533	total: 10.4s	remaining: 2m 40s
# 608:	learn: 0.6215408	total: 10.4s	remaining: 2m 40s
# 609:	learn: 0.6215350	total: 10.4s	remaining: 2m 39s
# 610:	learn: 0.6215169	total: 10.4s	remaining: 2m 39s
# 611:	learn: 0.6215035	total: 10.4s	remaining: 2m 39s
# 612:	learn: 0.6215018	total: 10.4s	remaining: 2m 39s
# 613:	learn: 0.6214948	total: 10.5s	remaining: 2m 39s
# 614:	learn: 0.6214693	total: 10.5s	remaining: 2m 39s
# 615:	learn: 0.6214511	total: 10.5s	remaining: 2m 39s
# 616:	learn: 0.6214392	total: 10.5s	remaining: 2m 39s
# 617:	learn: 0.6214361	total: 10.5s	remaining: 2m 39s
# 618:	learn: 0.6214238	total: 10.5s	remaining: 2m 39s
# 619:	learn: 0.6214171	total: 10.6s	remaining: 2m 39s
# 620:	learn: 0.6213915	total: 10.6s	remaining: 2m 39s
# 621:	learn: 0.6213863	total: 10.6s	remaining: 2m 39s
# 622:	learn: 0.6213807	total: 10.6s	remaining: 2m 39s
# 623:	learn: 0.6213653	total: 10.6s	remaining: 2m 39s
# 624:	learn: 0.6213617	total: 10.6s	remaining: 2m 39s
# 625:	learn: 0.6213402	total: 10.7s	remaining: 2m 39s
# 626:	learn: 0.6213357	total: 10.7s	remaining: 2m 39s
# 627:	learn: 0.6213187	total: 10.7s	remaining: 2m 39s
# 628:	learn: 0.6213139	total: 10.7s	remaining: 2m 39s
# 629:	learn: 0.6212932	total: 10.7s	remaining: 2m 39s
# 630:	learn: 0.6212848	total: 10.7s	remaining: 2m 39s
# 631:	learn: 0.6212815	total: 10.8s	remaining: 2m 39s
# 632:	learn: 0.6212540	total: 10.8s	remaining: 2m 39s
# 633:	learn: 0.6212343	total: 10.8s	remaining: 2m 39s
# 634:	learn: 0.6212313	total: 10.8s	remaining: 2m 39s
# 635:	learn: 0.6212313	total: 10.8s	remaining: 2m 39s
# 636:	learn: 0.6212294	total: 10.8s	remaining: 2m 39s
# 637:	learn: 0.6212216	total: 10.8s	remaining: 2m 39s
# 638:	learn: 0.6212127	total: 10.9s	remaining: 2m 39s
# 639:	learn: 0.6211996	total: 10.9s	remaining: 2m 39s
# 640:	learn: 0.6211741	total: 10.9s	remaining: 2m 39s
# 641:	learn: 0.6211475	total: 10.9s	remaining: 2m 39s
# 642:	learn: 0.6211098	total: 10.9s	remaining: 2m 39s
# 643:	learn: 0.6210983	total: 11s	remaining: 2m 39s
# 644:	learn: 0.6210878	total: 11s	remaining: 2m 39s
# 645:	learn: 0.6210586	total: 11s	remaining: 2m 39s
# 646:	learn: 0.6210516	total: 11s	remaining: 2m 39s
# 647:	learn: 0.6210467	total: 11s	remaining: 2m 39s
# 648:	learn: 0.6210389	total: 11s	remaining: 2m 39s
# 649:	learn: 0.6210355	total: 11.1s	remaining: 2m 39s
# 650:	learn: 0.6210329	total: 11.1s	remaining: 2m 39s
# 651:	learn: 0.6210329	total: 11.1s	remaining: 2m 38s
# 652:	learn: 0.6210320	total: 11.1s	remaining: 2m 38s
# 653:	learn: 0.6210215	total: 11.1s	remaining: 2m 38s
# 654:	learn: 0.6210107	total: 11.1s	remaining: 2m 38s
# 655:	learn: 0.6210031	total: 11.2s	remaining: 2m 38s
# 656:	learn: 0.6209614	total: 11.2s	remaining: 2m 38s
# 657:	learn: 0.6209352	total: 11.2s	remaining: 2m 38s
# 658:	learn: 0.6209282	total: 11.2s	remaining: 2m 38s
# 659:	learn: 0.6209122	total: 11.2s	remaining: 2m 38s
# 660:	learn: 0.6208914	total: 11.2s	remaining: 2m 38s
# 661:	learn: 0.6208860	total: 11.3s	remaining: 2m 38s
# 662:	learn: 0.6208799	total: 11.3s	remaining: 2m 38s
# 663:	learn: 0.6208475	total: 11.3s	remaining: 2m 38s
# 664:	learn: 0.6208423	total: 11.3s	remaining: 2m 38s
# 665:	learn: 0.6208277	total: 11.3s	remaining: 2m 38s
# 666:	learn: 0.6208124	total: 11.3s	remaining: 2m 38s
# 667:	learn: 0.6207995	total: 11.4s	remaining: 2m 38s
# 668:	learn: 0.6207937	total: 11.4s	remaining: 2m 38s
# 669:	learn: 0.6207773	total: 11.4s	remaining: 2m 38s
# 670:	learn: 0.6207665	total: 11.4s	remaining: 2m 38s
# 671:	learn: 0.6207607	total: 11.4s	remaining: 2m 38s
# 672:	learn: 0.6207317	total: 11.4s	remaining: 2m 38s
# 673:	learn: 0.6207072	total: 11.5s	remaining: 2m 38s
# 674:	learn: 0.6206974	total: 11.5s	remaining: 2m 38s
# 675:	learn: 0.6206840	total: 11.5s	remaining: 2m 38s
# 676:	learn: 0.6206716	total: 11.5s	remaining: 2m 38s
# 677:	learn: 0.6206610	total: 11.5s	remaining: 2m 38s
# 678:	learn: 0.6206594	total: 11.5s	remaining: 2m 38s
# 679:	learn: 0.6206567	total: 11.6s	remaining: 2m 38s
# 680:	learn: 0.6206271	total: 11.6s	remaining: 2m 38s
# 681:	learn: 0.6206213	total: 11.6s	remaining: 2m 38s
# 682:	learn: 0.6205953	total: 11.6s	remaining: 2m 38s
# 683:	learn: 0.6205845	total: 11.6s	remaining: 2m 38s
# 684:	learn: 0.6205818	total: 11.6s	remaining: 2m 38s
# 685:	learn: 0.6205610	total: 11.7s	remaining: 2m 38s
# 686:	learn: 0.6205501	total: 11.7s	remaining: 2m 38s
# 687:	learn: 0.6205307	total: 11.7s	remaining: 2m 38s
# 688:	learn: 0.6205213	total: 11.7s	remaining: 2m 38s
# 689:	learn: 0.6205009	total: 11.7s	remaining: 2m 38s
# 690:	learn: 0.6205009	total: 11.7s	remaining: 2m 38s
# 691:	learn: 0.6204876	total: 11.8s	remaining: 2m 38s
# 692:	learn: 0.6204794	total: 11.8s	remaining: 2m 38s
# 693:	learn: 0.6204615	total: 11.8s	remaining: 2m 38s
# 694:	learn: 0.6204460	total: 11.8s	remaining: 2m 38s
# 695:	learn: 0.6204401	total: 11.8s	remaining: 2m 38s
# 696:	learn: 0.6204330	total: 11.8s	remaining: 2m 38s
# 697:	learn: 0.6204089	total: 11.9s	remaining: 2m 38s
# 698:	learn: 0.6204089	total: 11.9s	remaining: 2m 38s
# 699:	learn: 0.6203978	total: 11.9s	remaining: 2m 37s
# 700:	learn: 0.6203959	total: 11.9s	remaining: 2m 37s
# 701:	learn: 0.6203929	total: 11.9s	remaining: 2m 37s
# 702:	learn: 0.6203665	total: 11.9s	remaining: 2m 37s
# 703:	learn: 0.6203644	total: 12s	remaining: 2m 37s
# 704:	learn: 0.6203545	total: 12s	remaining: 2m 37s
# 705:	learn: 0.6203492	total: 12s	remaining: 2m 37s
# 706:	learn: 0.6203363	total: 12s	remaining: 2m 37s
# 707:	learn: 0.6203202	total: 12s	remaining: 2m 37s
# 708:	learn: 0.6203146	total: 12s	remaining: 2m 37s
# 709:	learn: 0.6203082	total: 12s	remaining: 2m 37s
# 710:	learn: 0.6202949	total: 12.1s	remaining: 2m 37s
# 711:	learn: 0.6202732	total: 12.1s	remaining: 2m 37s
# 712:	learn: 0.6202626	total: 12.1s	remaining: 2m 37s
# 713:	learn: 0.6202617	total: 12.1s	remaining: 2m 37s
# 714:	learn: 0.6202419	total: 12.1s	remaining: 2m 37s
# 715:	learn: 0.6202211	total: 12.2s	remaining: 2m 37s
# 716:	learn: 0.6202161	total: 12.2s	remaining: 2m 37s
# 717:	learn: 0.6202161	total: 12.2s	remaining: 2m 37s
# 718:	learn: 0.6202111	total: 12.2s	remaining: 2m 37s
# 719:	learn: 0.6202053	total: 12.2s	remaining: 2m 37s
# 720:	learn: 0.6202018	total: 12.2s	remaining: 2m 37s
# 721:	learn: 0.6201976	total: 12.2s	remaining: 2m 37s
# 722:	learn: 0.6201945	total: 12.3s	remaining: 2m 37s
# 723:	learn: 0.6201945	total: 12.3s	remaining: 2m 37s
# 724:	learn: 0.6201837	total: 12.3s	remaining: 2m 37s
# 725:	learn: 0.6201760	total: 12.3s	remaining: 2m 37s
# 726:	learn: 0.6201712	total: 12.3s	remaining: 2m 37s
# 727:	learn: 0.6201449	total: 12.3s	remaining: 2m 37s
# 728:	learn: 0.6201400	total: 12.4s	remaining: 2m 37s
# 729:	learn: 0.6201306	total: 12.4s	remaining: 2m 37s
# 730:	learn: 0.6201268	total: 12.4s	remaining: 2m 37s
# 731:	learn: 0.6201237	total: 12.4s	remaining: 2m 37s
# 732:	learn: 0.6201197	total: 12.4s	remaining: 2m 37s
# 733:	learn: 0.6201095	total: 12.4s	remaining: 2m 37s
# 734:	learn: 0.6201088	total: 12.5s	remaining: 2m 37s
# 735:	learn: 0.6200986	total: 12.5s	remaining: 2m 37s
# 736:	learn: 0.6200937	total: 12.5s	remaining: 2m 37s
# 737:	learn: 0.6200852	total: 12.5s	remaining: 2m 37s
# 738:	learn: 0.6200736	total: 12.5s	remaining: 2m 37s
# 739:	learn: 0.6200464	total: 12.5s	remaining: 2m 37s
# 740:	learn: 0.6200412	total: 12.6s	remaining: 2m 36s
# 741:	learn: 0.6200354	total: 12.6s	remaining: 2m 36s
# 742:	learn: 0.6200310	total: 12.6s	remaining: 2m 36s
# 743:	learn: 0.6200231	total: 12.6s	remaining: 2m 36s
# 744:	learn: 0.6200190	total: 12.6s	remaining: 2m 36s
# 745:	learn: 0.6200153	total: 12.7s	remaining: 2m 36s
# 746:	learn: 0.6200089	total: 12.7s	remaining: 2m 36s
# 747:	learn: 0.6200010	total: 12.7s	remaining: 2m 36s
# 748:	learn: 0.6199946	total: 12.7s	remaining: 2m 36s
# 749:	learn: 0.6199724	total: 12.7s	remaining: 2m 36s
# 750:	learn: 0.6199722	total: 12.7s	remaining: 2m 36s
# 751:	learn: 0.6199668	total: 12.7s	remaining: 2m 36s
# 752:	learn: 0.6199637	total: 12.8s	remaining: 2m 36s
# 753:	learn: 0.6199574	total: 12.8s	remaining: 2m 36s
# 754:	learn: 0.6199532	total: 12.8s	remaining: 2m 36s
# 755:	learn: 0.6199406	total: 12.8s	remaining: 2m 36s
# 756:	learn: 0.6199234	total: 12.8s	remaining: 2m 36s
# 757:	learn: 0.6199150	total: 12.8s	remaining: 2m 36s
# 758:	learn: 0.6199136	total: 12.9s	remaining: 2m 36s
# 759:	learn: 0.6199087	total: 12.9s	remaining: 2m 36s
# 760:	learn: 0.6199011	total: 12.9s	remaining: 2m 36s
# 761:	learn: 0.6198964	total: 12.9s	remaining: 2m 36s
# 762:	learn: 0.6198763	total: 12.9s	remaining: 2m 36s
# 763:	learn: 0.6198698	total: 12.9s	remaining: 2m 36s
# 764:	learn: 0.6198698	total: 12.9s	remaining: 2m 36s
# 765:	learn: 0.6198614	total: 13s	remaining: 2m 36s
# 766:	learn: 0.6198454	total: 13s	remaining: 2m 36s
# 767:	learn: 0.6198262	total: 13s	remaining: 2m 36s
# 768:	learn: 0.6198055	total: 13s	remaining: 2m 36s
# 769:	learn: 0.6197977	total: 13s	remaining: 2m 36s
# 770:	learn: 0.6197965	total: 13s	remaining: 2m 36s
# 771:	learn: 0.6197965	total: 13.1s	remaining: 2m 36s
# 772:	learn: 0.6197780	total: 13.1s	remaining: 2m 35s
# 773:	learn: 0.6197688	total: 13.1s	remaining: 2m 35s
# 774:	learn: 0.6197637	total: 13.1s	remaining: 2m 35s
# 775:	learn: 0.6197508	total: 13.1s	remaining: 2m 35s
# 776:	learn: 0.6197341	total: 13.1s	remaining: 2m 35s
# 777:	learn: 0.6197195	total: 13.1s	remaining: 2m 35s
# 778:	learn: 0.6196780	total: 13.2s	remaining: 2m 35s
# 779:	learn: 0.6196717	total: 13.2s	remaining: 2m 35s
# 780:	learn: 0.6196710	total: 13.2s	remaining: 2m 35s
# 781:	learn: 0.6196550	total: 13.2s	remaining: 2m 35s
# 782:	learn: 0.6196518	total: 13.2s	remaining: 2m 35s
# 783:	learn: 0.6196295	total: 13.2s	remaining: 2m 35s
# 784:	learn: 0.6196209	total: 13.3s	remaining: 2m 35s
# 785:	learn: 0.6195888	total: 13.3s	remaining: 2m 35s
# 786:	learn: 0.6195750	total: 13.3s	remaining: 2m 35s
# 787:	learn: 0.6195750	total: 13.3s	remaining: 2m 35s
# 788:	learn: 0.6195719	total: 13.3s	remaining: 2m 35s
# 789:	learn: 0.6195683	total: 13.3s	remaining: 2m 35s
# 790:	learn: 0.6195636	total: 13.3s	remaining: 2m 35s
# 791:	learn: 0.6195572	total: 13.3s	remaining: 2m 35s
# 792:	learn: 0.6195537	total: 13.4s	remaining: 2m 35s
# 793:	learn: 0.6195475	total: 13.4s	remaining: 2m 35s
# 794:	learn: 0.6194895	total: 13.4s	remaining: 2m 35s
# 795:	learn: 0.6194807	total: 13.4s	remaining: 2m 35s
# 796:	learn: 0.6194646	total: 13.4s	remaining: 2m 35s
# 797:	learn: 0.6194249	total: 13.4s	remaining: 2m 35s
# 798:	learn: 0.6194249	total: 13.5s	remaining: 2m 34s
# 799:	learn: 0.6194202	total: 13.5s	remaining: 2m 34s
# 800:	learn: 0.6193983	total: 13.5s	remaining: 2m 34s
# 801:	learn: 0.6193641	total: 13.5s	remaining: 2m 34s
# 802:	learn: 0.6193557	total: 13.5s	remaining: 2m 34s
# 803:	learn: 0.6193544	total: 13.5s	remaining: 2m 34s
# 804:	learn: 0.6193451	total: 13.5s	remaining: 2m 34s
# 805:	learn: 0.6193396	total: 13.6s	remaining: 2m 34s
# 806:	learn: 0.6193256	total: 13.6s	remaining: 2m 34s
# 807:	learn: 0.6193220	total: 13.6s	remaining: 2m 34s
# 808:	learn: 0.6193173	total: 13.6s	remaining: 2m 34s
# 809:	learn: 0.6193095	total: 13.6s	remaining: 2m 34s
# 810:	learn: 0.6193058	total: 13.6s	remaining: 2m 34s
# 811:	learn: 0.6192946	total: 13.7s	remaining: 2m 34s
# 812:	learn: 0.6192946	total: 13.7s	remaining: 2m 34s
# 813:	learn: 0.6192921	total: 13.7s	remaining: 2m 34s
# 814:	learn: 0.6192869	total: 13.7s	remaining: 2m 34s
# 815:	learn: 0.6192776	total: 13.7s	remaining: 2m 34s
# 816:	learn: 0.6192747	total: 13.7s	remaining: 2m 34s
# 817:	learn: 0.6192678	total: 13.7s	remaining: 2m 34s
# 818:	learn: 0.6192606	total: 13.8s	remaining: 2m 34s
# 819:	learn: 0.6192354	total: 13.8s	remaining: 2m 34s
# 820:	learn: 0.6192354	total: 13.8s	remaining: 2m 34s
# 821:	learn: 0.6192300	total: 13.8s	remaining: 2m 34s
# 822:	learn: 0.6192280	total: 13.8s	remaining: 2m 34s
# 823:	learn: 0.6192261	total: 13.8s	remaining: 2m 34s
# 824:	learn: 0.6192261	total: 13.8s	remaining: 2m 34s
# 825:	learn: 0.6192057	total: 13.9s	remaining: 2m 34s
# 826:	learn: 0.6192057	total: 13.9s	remaining: 2m 33s
# 827:	learn: 0.6191951	total: 13.9s	remaining: 2m 33s
# 828:	learn: 0.6191941	total: 13.9s	remaining: 2m 33s
# 829:	learn: 0.6191941	total: 13.9s	remaining: 2m 33s
# 830:	learn: 0.6191902	total: 13.9s	remaining: 2m 33s
# 831:	learn: 0.6191885	total: 14s	remaining: 2m 33s
# 832:	learn: 0.6191778	total: 14s	remaining: 2m 33s
# 833:	learn: 0.6191770	total: 14s	remaining: 2m 33s
# 834:	learn: 0.6191629	total: 14s	remaining: 2m 33s
# 835:	learn: 0.6191534	total: 14s	remaining: 2m 33s
# 836:	learn: 0.6191534	total: 14s	remaining: 2m 33s
# 837:	learn: 0.6191457	total: 14.1s	remaining: 2m 33s
# 838:	learn: 0.6191431	total: 14.1s	remaining: 2m 33s
# 839:	learn: 0.6191398	total: 14.1s	remaining: 2m 33s
# 840:	learn: 0.6191341	total: 14.1s	remaining: 2m 33s
# 841:	learn: 0.6191261	total: 14.1s	remaining: 2m 33s
# 842:	learn: 0.6191215	total: 14.1s	remaining: 2m 33s
# 843:	learn: 0.6191087	total: 14.2s	remaining: 2m 33s
# 844:	learn: 0.6191064	total: 14.2s	remaining: 2m 33s
# 845:	learn: 0.6190939	total: 14.2s	remaining: 2m 33s
# 846:	learn: 0.6190883	total: 14.2s	remaining: 2m 33s
# 847:	learn: 0.6190858	total: 14.2s	remaining: 2m 33s
# 848:	learn: 0.6190728	total: 14.3s	remaining: 2m 33s
# 849:	learn: 0.6190560	total: 14.3s	remaining: 2m 33s
# 850:	learn: 0.6190401	total: 14.3s	remaining: 2m 33s
# 851:	learn: 0.6190243	total: 14.3s	remaining: 2m 33s
# 852:	learn: 0.6190168	total: 14.3s	remaining: 2m 33s
# 853:	learn: 0.6190026	total: 14.3s	remaining: 2m 33s
# 854:	learn: 0.6189953	total: 14.4s	remaining: 2m 33s
# 855:	learn: 0.6189847	total: 14.4s	remaining: 2m 33s
# 856:	learn: 0.6189811	total: 14.4s	remaining: 2m 33s
# 857:	learn: 0.6189800	total: 14.4s	remaining: 2m 33s
# 858:	learn: 0.6189608	total: 14.4s	remaining: 2m 33s
# 859:	learn: 0.6189608	total: 14.4s	remaining: 2m 33s
# 860:	learn: 0.6189547	total: 14.5s	remaining: 2m 33s
# 861:	learn: 0.6189456	total: 14.5s	remaining: 2m 33s
# 862:	learn: 0.6189354	total: 14.5s	remaining: 2m 33s
# 863:	learn: 0.6189258	total: 14.5s	remaining: 2m 33s
# 864:	learn: 0.6189140	total: 14.5s	remaining: 2m 33s
# 865:	learn: 0.6189113	total: 14.5s	remaining: 2m 33s
# 866:	learn: 0.6188988	total: 14.6s	remaining: 2m 33s
# 867:	learn: 0.6188933	total: 14.6s	remaining: 2m 33s
# 868:	learn: 0.6188920	total: 14.6s	remaining: 2m 33s
# 869:	learn: 0.6188885	total: 14.6s	remaining: 2m 33s
# 870:	learn: 0.6188836	total: 14.6s	remaining: 2m 33s
# 871:	learn: 0.6188780	total: 14.6s	remaining: 2m 33s
# 872:	learn: 0.6188665	total: 14.7s	remaining: 2m 33s
# 873:	learn: 0.6188590	total: 14.7s	remaining: 2m 33s
# 874:	learn: 0.6188457	total: 14.7s	remaining: 2m 33s
# 875:	learn: 0.6188351	total: 14.7s	remaining: 2m 33s
# 876:	learn: 0.6188244	total: 14.7s	remaining: 2m 33s
# 877:	learn: 0.6188223	total: 14.8s	remaining: 2m 33s
# 878:	learn: 0.6188172	total: 14.8s	remaining: 2m 33s
# 879:	learn: 0.6188064	total: 14.8s	remaining: 2m 33s
# 880:	learn: 0.6188056	total: 14.8s	remaining: 2m 33s
# 881:	learn: 0.6187784	total: 14.8s	remaining: 2m 33s
# 882:	learn: 0.6187750	total: 14.8s	remaining: 2m 33s
# 883:	learn: 0.6187749	total: 14.9s	remaining: 2m 33s
# 884:	learn: 0.6187606	total: 14.9s	remaining: 2m 33s
# 885:	learn: 0.6187582	total: 14.9s	remaining: 2m 33s
# 886:	learn: 0.6187519	total: 14.9s	remaining: 2m 33s
# 887:	learn: 0.6187501	total: 14.9s	remaining: 2m 33s
# 888:	learn: 0.6187463	total: 14.9s	remaining: 2m 33s
# 889:	learn: 0.6187429	total: 15s	remaining: 2m 33s
# 890:	learn: 0.6187383	total: 15s	remaining: 2m 33s
# 891:	learn: 0.6187359	total: 15s	remaining: 2m 33s
# 892:	learn: 0.6187296	total: 15s	remaining: 2m 33s
# 893:	learn: 0.6187258	total: 15s	remaining: 2m 33s
# 894:	learn: 0.6187254	total: 15s	remaining: 2m 33s
# 895:	learn: 0.6187234	total: 15.1s	remaining: 2m 33s
# 896:	learn: 0.6187199	total: 15.1s	remaining: 2m 33s
# 897:	learn: 0.6187158	total: 15.1s	remaining: 2m 33s
# 898:	learn: 0.6187082	total: 15.1s	remaining: 2m 33s
# 899:	learn: 0.6187031	total: 15.1s	remaining: 2m 33s
# 900:	learn: 0.6187031	total: 15.1s	remaining: 2m 32s
# 901:	learn: 0.6186980	total: 15.2s	remaining: 2m 32s
# 902:	learn: 0.6186906	total: 15.2s	remaining: 2m 32s
# 903:	learn: 0.6186855	total: 15.2s	remaining: 2m 32s
# 904:	learn: 0.6186823	total: 15.2s	remaining: 2m 32s
# 905:	learn: 0.6186795	total: 15.2s	remaining: 2m 32s
# 906:	learn: 0.6186795	total: 15.2s	remaining: 2m 32s
# 907:	learn: 0.6186757	total: 15.3s	remaining: 2m 32s
# 908:	learn: 0.6186635	total: 15.3s	remaining: 2m 32s
# 909:	learn: 0.6186520	total: 15.3s	remaining: 2m 32s
# 910:	learn: 0.6186442	total: 15.3s	remaining: 2m 32s
# ...
# 9726:	learn: 0.6139341	total: 2m 42s	remaining: 4.57s
# 9727:	learn: 0.6139341	total: 2m 42s	remaining: 4.55s
# 9728:	learn: 0.6139341	total: 2m 42s	remaining: 4.53s
# 9729:	learn: 0.6139341	total: 2m 42s	remaining: 4.51s
# 9730:	learn: 0.6139341	total: 2m 42s	remaining: 4.5s
# 9731:	learn: 0.6139341	total: 2m 42s	remaining: 4.48s
# 9732:	learn: 0.6139340	total: 2m 42s	remaining: 4.46s
# 9733:	learn: 0.6139340	total: 2m 42s	remaining: 4.45s
# 9734:	learn: 0.6139340	total: 2m 42s	remaining: 4.43s
# 9735:	learn: 0.6139340	total: 2m 42s	remaining: 4.42s
# 9736:	learn: 0.6139340	total: 2m 42s	remaining: 4.4s
# 9737:	learn: 0.6139340	total: 2m 42s	remaining: 4.38s
# 9738:	learn: 0.6139339	total: 2m 42s	remaining: 4.37s
# 9739:	learn: 0.6139339	total: 2m 42s	remaining: 4.35s
# 9740:	learn: 0.6139338	total: 2m 42s	remaining: 4.33s
# 9741:	learn: 0.6139338	total: 2m 42s	remaining: 4.32s
# 9742:	learn: 0.6139338	total: 2m 42s	remaining: 4.3s
# 9743:	learn: 0.6139338	total: 2m 42s	remaining: 4.28s
# 9744:	learn: 0.6139337	total: 2m 43s	remaining: 4.26s
# 9745:	learn: 0.6139337	total: 2m 43s	remaining: 4.25s
# 9746:	learn: 0.6139337	total: 2m 43s	remaining: 4.23s
# 9747:	learn: 0.6139337	total: 2m 43s	remaining: 4.21s
# 9748:	learn: 0.6139337	total: 2m 43s	remaining: 4.2s
# 9749:	learn: 0.6139337	total: 2m 43s	remaining: 4.18s
# 9750:	learn: 0.6139337	total: 2m 43s	remaining: 4.17s
# 9751:	learn: 0.6139337	total: 2m 43s	remaining: 4.15s
# 9752:	learn: 0.6139337	total: 2m 43s	remaining: 4.13s
# 9753:	learn: 0.6139337	total: 2m 43s	remaining: 4.12s
# 9754:	learn: 0.6139337	total: 2m 43s	remaining: 4.1s
# 9755:	learn: 0.6139337	total: 2m 43s	remaining: 4.08s
# 9756:	learn: 0.6139337	total: 2m 43s	remaining: 4.06s
# 9757:	learn: 0.6139337	total: 2m 43s	remaining: 4.05s
# 9758:	learn: 0.6139337	total: 2m 43s	remaining: 4.03s
# 9759:	learn: 0.6139336	total: 2m 43s	remaining: 4.01s
# 9760:	learn: 0.6139336	total: 2m 43s	remaining: 4s
# 9761:	learn: 0.6139336	total: 2m 43s	remaining: 3.98s
# 9762:	learn: 0.6139336	total: 2m 43s	remaining: 3.96s
# 9763:	learn: 0.6139336	total: 2m 43s	remaining: 3.95s
# 9764:	learn: 0.6139335	total: 2m 43s	remaining: 3.93s
# 9765:	learn: 0.6139335	total: 2m 43s	remaining: 3.91s
# 9766:	learn: 0.6139335	total: 2m 43s	remaining: 3.9s
# 9767:	learn: 0.6139335	total: 2m 43s	remaining: 3.88s
# 9768:	learn: 0.6139335	total: 2m 43s	remaining: 3.86s
# 9769:	learn: 0.6139335	total: 2m 43s	remaining: 3.85s
# 9770:	learn: 0.6139335	total: 2m 43s	remaining: 3.83s
# 9771:	learn: 0.6139335	total: 2m 43s	remaining: 3.81s
# 9772:	learn: 0.6139334	total: 2m 43s	remaining: 3.8s
# 9773:	learn: 0.6139334	total: 2m 43s	remaining: 3.78s
# 9774:	learn: 0.6139334	total: 2m 43s	remaining: 3.76s
# 9775:	learn: 0.6139334	total: 2m 43s	remaining: 3.75s
# 9776:	learn: 0.6139334	total: 2m 43s	remaining: 3.73s
# 9777:	learn: 0.6139334	total: 2m 43s	remaining: 3.71s
# 9778:	learn: 0.6139333	total: 2m 43s	remaining: 3.7s
# 9779:	learn: 0.6139331	total: 2m 43s	remaining: 3.68s
# 9780:	learn: 0.6139331	total: 2m 43s	remaining: 3.66s
# 9781:	learn: 0.6139331	total: 2m 43s	remaining: 3.65s
# 9782:	learn: 0.6139330	total: 2m 43s	remaining: 3.63s
# 9783:	learn: 0.6139330	total: 2m 43s	remaining: 3.61s
# 9784:	learn: 0.6139330	total: 2m 43s	remaining: 3.6s
# 9785:	learn: 0.6139329	total: 2m 43s	remaining: 3.58s
# 9786:	learn: 0.6139329	total: 2m 43s	remaining: 3.56s
# 9787:	learn: 0.6139329	total: 2m 43s	remaining: 3.55s
# 9788:	learn: 0.6139329	total: 2m 43s	remaining: 3.53s
# 9789:	learn: 0.6139328	total: 2m 43s	remaining: 3.51s
# 9790:	learn: 0.6139328	total: 2m 43s	remaining: 3.5s
# 9791:	learn: 0.6139328	total: 2m 43s	remaining: 3.48s
# 9792:	learn: 0.6139327	total: 2m 43s	remaining: 3.46s
# 9793:	learn: 0.6139327	total: 2m 43s	remaining: 3.45s
# 9794:	learn: 0.6139327	total: 2m 43s	remaining: 3.43s
# 9795:	learn: 0.6139327	total: 2m 43s	remaining: 3.41s
# 9796:	learn: 0.6139326	total: 2m 43s	remaining: 3.4s
# 9797:	learn: 0.6139326	total: 2m 43s	remaining: 3.38s
# 9798:	learn: 0.6139326	total: 2m 43s	remaining: 3.36s
# 9799:	learn: 0.6139326	total: 2m 43s	remaining: 3.35s
# 9800:	learn: 0.6139326	total: 2m 43s	remaining: 3.33s
# 9801:	learn: 0.6139326	total: 2m 44s	remaining: 3.31s
# 9802:	learn: 0.6139326	total: 2m 44s	remaining: 3.3s
# 9803:	learn: 0.6139326	total: 2m 44s	remaining: 3.28s
# 9804:	learn: 0.6139325	total: 2m 44s	remaining: 3.26s
# 9805:	learn: 0.6139325	total: 2m 44s	remaining: 3.25s
# 9806:	learn: 0.6139325	total: 2m 44s	remaining: 3.23s
# 9807:	learn: 0.6139325	total: 2m 44s	remaining: 3.21s
# 9808:	learn: 0.6139324	total: 2m 44s	remaining: 3.2s
# 9809:	learn: 0.6139324	total: 2m 44s	remaining: 3.18s
# 9810:	learn: 0.6139324	total: 2m 44s	remaining: 3.16s
# 9811:	learn: 0.6139324	total: 2m 44s	remaining: 3.15s
# 9812:	learn: 0.6139324	total: 2m 44s	remaining: 3.13s
# 9813:	learn: 0.6139324	total: 2m 44s	remaining: 3.11s
# 9814:	learn: 0.6139324	total: 2m 44s	remaining: 3.1s
# 9815:	learn: 0.6139323	total: 2m 44s	remaining: 3.08s
# 9816:	learn: 0.6139323	total: 2m 44s	remaining: 3.06s
# 9817:	learn: 0.6139322	total: 2m 44s	remaining: 3.04s
# 9818:	learn: 0.6139322	total: 2m 44s	remaining: 3.03s
# 9819:	learn: 0.6139322	total: 2m 44s	remaining: 3.01s
# 9820:	learn: 0.6139322	total: 2m 44s	remaining: 3s
# 9821:	learn: 0.6139321	total: 2m 44s	remaining: 2.98s
# 9822:	learn: 0.6139320	total: 2m 44s	remaining: 2.96s
# 9823:	learn: 0.6139320	total: 2m 44s	remaining: 2.94s
# 9824:	learn: 0.6139320	total: 2m 44s	remaining: 2.93s
# 9825:	learn: 0.6139320	total: 2m 44s	remaining: 2.91s
# 9826:	learn: 0.6139320	total: 2m 44s	remaining: 2.89s
# 9827:	learn: 0.6139320	total: 2m 44s	remaining: 2.88s
# 9828:	learn: 0.6139320	total: 2m 44s	remaining: 2.86s
# 9829:	learn: 0.6139320	total: 2m 44s	remaining: 2.84s
# 9830:	learn: 0.6139319	total: 2m 44s	remaining: 2.83s
# 9831:	learn: 0.6139319	total: 2m 44s	remaining: 2.81s
# 9832:	learn: 0.6139319	total: 2m 44s	remaining: 2.79s
# 9833:	learn: 0.6139319	total: 2m 44s	remaining: 2.78s
# 9834:	learn: 0.6139319	total: 2m 44s	remaining: 2.76s
# 9835:	learn: 0.6139319	total: 2m 44s	remaining: 2.74s
# 9836:	learn: 0.6139319	total: 2m 44s	remaining: 2.73s
# 9837:	learn: 0.6139319	total: 2m 44s	remaining: 2.71s
# 9838:	learn: 0.6139318	total: 2m 44s	remaining: 2.69s
# 9839:	learn: 0.6139318	total: 2m 44s	remaining: 2.68s
# 9840:	learn: 0.6139318	total: 2m 44s	remaining: 2.66s
# 9841:	learn: 0.6139318	total: 2m 44s	remaining: 2.64s
# 9842:	learn: 0.6139318	total: 2m 44s	remaining: 2.63s
# 9843:	learn: 0.6139318	total: 2m 44s	remaining: 2.61s
# 9844:	learn: 0.6139318	total: 2m 44s	remaining: 2.59s
# 9845:	learn: 0.6139317	total: 2m 44s	remaining: 2.58s
# 9846:	learn: 0.6139317	total: 2m 44s	remaining: 2.56s
# 9847:	learn: 0.6139317	total: 2m 44s	remaining: 2.54s
# 9848:	learn: 0.6139317	total: 2m 44s	remaining: 2.53s
# 9849:	learn: 0.6139317	total: 2m 44s	remaining: 2.51s
# 9850:	learn: 0.6139317	total: 2m 44s	remaining: 2.49s
# 9851:	learn: 0.6139316	total: 2m 44s	remaining: 2.48s
# 9852:	learn: 0.6139316	total: 2m 44s	remaining: 2.46s
# 9853:	learn: 0.6139316	total: 2m 44s	remaining: 2.44s
# 9854:	learn: 0.6139316	total: 2m 44s	remaining: 2.43s
# 9855:	learn: 0.6139316	total: 2m 44s	remaining: 2.41s
# 9856:	learn: 0.6139316	total: 2m 44s	remaining: 2.39s
# 9857:	learn: 0.6139316	total: 2m 44s	remaining: 2.38s
# 9858:	learn: 0.6139316	total: 2m 44s	remaining: 2.36s
# 9859:	learn: 0.6139316	total: 2m 44s	remaining: 2.34s
# 9860:	learn: 0.6139316	total: 2m 45s	remaining: 2.33s
# 9861:	learn: 0.6139316	total: 2m 45s	remaining: 2.31s
# 9862:	learn: 0.6139316	total: 2m 45s	remaining: 2.29s
# 9863:	learn: 0.6139315	total: 2m 45s	remaining: 2.27s
# 9864:	learn: 0.6139315	total: 2m 45s	remaining: 2.26s
# 9865:	learn: 0.6139315	total: 2m 45s	remaining: 2.24s
# 9866:	learn: 0.6139315	total: 2m 45s	remaining: 2.23s
# 9867:	learn: 0.6139315	total: 2m 45s	remaining: 2.21s
# 9868:	learn: 0.6139315	total: 2m 45s	remaining: 2.19s
# 9869:	learn: 0.6139315	total: 2m 45s	remaining: 2.17s
# 9870:	learn: 0.6139315	total: 2m 45s	remaining: 2.16s
# 9871:	learn: 0.6139314	total: 2m 45s	remaining: 2.14s
# 9872:	learn: 0.6139314	total: 2m 45s	remaining: 2.12s
# 9873:	learn: 0.6139314	total: 2m 45s	remaining: 2.11s
# 9874:	learn: 0.6139314	total: 2m 45s	remaining: 2.09s
# 9875:	learn: 0.6139314	total: 2m 45s	remaining: 2.07s
# 9876:	learn: 0.6139313	total: 2m 45s	remaining: 2.06s
# 9877:	learn: 0.6139313	total: 2m 45s	remaining: 2.04s
# 9878:	learn: 0.6139313	total: 2m 45s	remaining: 2.02s
# 9879:	learn: 0.6139313	total: 2m 45s	remaining: 2.01s
# 9880:	learn: 0.6139313	total: 2m 45s	remaining: 1.99s
# 9881:	learn: 0.6139313	total: 2m 45s	remaining: 1.97s
# 9882:	learn: 0.6139313	total: 2m 45s	remaining: 1.96s
# 9883:	learn: 0.6139313	total: 2m 45s	remaining: 1.94s
# 9884:	learn: 0.6139313	total: 2m 45s	remaining: 1.92s
# 9885:	learn: 0.6139313	total: 2m 45s	remaining: 1.91s
# 9886:	learn: 0.6139313	total: 2m 45s	remaining: 1.89s
# 9887:	learn: 0.6139313	total: 2m 45s	remaining: 1.87s
# 9888:	learn: 0.6139313	total: 2m 45s	remaining: 1.86s
# 9889:	learn: 0.6139312	total: 2m 45s	remaining: 1.84s
# 9890:	learn: 0.6139312	total: 2m 45s	remaining: 1.82s
# 9891:	learn: 0.6139312	total: 2m 45s	remaining: 1.81s
# 9892:	learn: 0.6139312	total: 2m 45s	remaining: 1.79s
# 9893:	learn: 0.6139312	total: 2m 45s	remaining: 1.77s
# 9894:	learn: 0.6139311	total: 2m 45s	remaining: 1.76s
# 9895:	learn: 0.6139311	total: 2m 45s	remaining: 1.74s
# 9896:	learn: 0.6139311	total: 2m 45s	remaining: 1.72s
# 9897:	learn: 0.6139311	total: 2m 45s	remaining: 1.71s
# 9898:	learn: 0.6139311	total: 2m 45s	remaining: 1.69s
# 9899:	learn: 0.6139311	total: 2m 45s	remaining: 1.67s
# 9900:	learn: 0.6139311	total: 2m 45s	remaining: 1.66s
# 9901:	learn: 0.6139311	total: 2m 45s	remaining: 1.64s
# 9902:	learn: 0.6139310	total: 2m 45s	remaining: 1.62s
# 9903:	learn: 0.6139310	total: 2m 45s	remaining: 1.61s
# 9904:	learn: 0.6139310	total: 2m 45s	remaining: 1.59s
# 9905:	learn: 0.6139310	total: 2m 45s	remaining: 1.57s
# 9906:	learn: 0.6139310	total: 2m 45s	remaining: 1.56s
# 9907:	learn: 0.6139309	total: 2m 45s	remaining: 1.54s
# 9908:	learn: 0.6139309	total: 2m 45s	remaining: 1.52s
# 9909:	learn: 0.6139309	total: 2m 45s	remaining: 1.5s
# 9910:	learn: 0.6139309	total: 2m 45s	remaining: 1.49s
# 9911:	learn: 0.6139309	total: 2m 45s	remaining: 1.47s
# 9912:	learn: 0.6139309	total: 2m 45s	remaining: 1.46s
# 9913:	learn: 0.6139309	total: 2m 45s	remaining: 1.44s
# 9914:	learn: 0.6139309	total: 2m 45s	remaining: 1.42s
# 9915:	learn: 0.6139309	total: 2m 45s	remaining: 1.41s
# 9916:	learn: 0.6139309	total: 2m 45s	remaining: 1.39s
# 9917:	learn: 0.6139309	total: 2m 45s	remaining: 1.37s
# 9918:	learn: 0.6139309	total: 2m 45s	remaining: 1.35s
# 9919:	learn: 0.6139309	total: 2m 46s	remaining: 1.34s
# 9920:	learn: 0.6139308	total: 2m 46s	remaining: 1.32s
# 9921:	learn: 0.6139308	total: 2m 46s	remaining: 1.3s
# 9922:	learn: 0.6139308	total: 2m 46s	remaining: 1.29s
# 9923:	learn: 0.6139308	total: 2m 46s	remaining: 1.27s
# 9924:	learn: 0.6139308	total: 2m 46s	remaining: 1.25s
# 9925:	learn: 0.6139308	total: 2m 46s	remaining: 1.24s
# 9926:	learn: 0.6139308	total: 2m 46s	remaining: 1.22s
# 9927:	learn: 0.6139308	total: 2m 46s	remaining: 1.2s
# 9928:	learn: 0.6139308	total: 2m 46s	remaining: 1.19s
# 9929:	learn: 0.6139308	total: 2m 46s	remaining: 1.17s
# 9930:	learn: 0.6139308	total: 2m 46s	remaining: 1.15s
# 9931:	learn: 0.6139308	total: 2m 46s	remaining: 1.14s
# 9932:	learn: 0.6139308	total: 2m 46s	remaining: 1.12s
# 9933:	learn: 0.6139308	total: 2m 46s	remaining: 1.1s
# 9934:	learn: 0.6139308	total: 2m 46s	remaining: 1.09s
# 9935:	learn: 0.6139307	total: 2m 46s	remaining: 1.07s
# 9936:	learn: 0.6139307	total: 2m 46s	remaining: 1.05s
# 9937:	learn: 0.6139306	total: 2m 46s	remaining: 1.04s
# 9938:	learn: 0.6139306	total: 2m 46s	remaining: 1.02s
# 9939:	learn: 0.6139304	total: 2m 46s	remaining: 1s
# 9940:	learn: 0.6139304	total: 2m 46s	remaining: 987ms
# 9941:	learn: 0.6139302	total: 2m 46s	remaining: 971ms
# 9942:	learn: 0.6139302	total: 2m 46s	remaining: 954ms
# 9943:	learn: 0.6139302	total: 2m 46s	remaining: 937ms
# 9944:	learn: 0.6139302	total: 2m 46s	remaining: 920ms
# 9945:	learn: 0.6139302	total: 2m 46s	remaining: 904ms
# 9946:	learn: 0.6139302	total: 2m 46s	remaining: 887ms
# 9947:	learn: 0.6139302	total: 2m 46s	remaining: 870ms
# 9948:	learn: 0.6139301	total: 2m 46s	remaining: 854ms
# 9949:	learn: 0.6139301	total: 2m 46s	remaining: 837ms
# 9950:	learn: 0.6139301	total: 2m 46s	remaining: 820ms
# 9951:	learn: 0.6139301	total: 2m 46s	remaining: 803ms
# 9952:	learn: 0.6139301	total: 2m 46s	remaining: 787ms
# 9953:	learn: 0.6139301	total: 2m 46s	remaining: 770ms
# 9954:	learn: 0.6139301	total: 2m 46s	remaining: 753ms
# 9955:	learn: 0.6139301	total: 2m 46s	remaining: 736ms
# 9956:	learn: 0.6139301	total: 2m 46s	remaining: 720ms
# 9957:	learn: 0.6139301	total: 2m 46s	remaining: 703ms
# 9958:	learn: 0.6139297	total: 2m 46s	remaining: 686ms
# 9959:	learn: 0.6139297	total: 2m 46s	remaining: 669ms
# 9960:	learn: 0.6139297	total: 2m 46s	remaining: 653ms
# 9961:	learn: 0.6139297	total: 2m 46s	remaining: 636ms
# 9962:	learn: 0.6139297	total: 2m 46s	remaining: 619ms
# 9963:	learn: 0.6139296	total: 2m 46s	remaining: 602ms
# 9964:	learn: 0.6139296	total: 2m 46s	remaining: 586ms
# 9965:	learn: 0.6139296	total: 2m 46s	remaining: 569ms
# 9966:	learn: 0.6139296	total: 2m 46s	remaining: 552ms
# 9967:	learn: 0.6139296	total: 2m 46s	remaining: 536ms
# 9968:	learn: 0.6139296	total: 2m 46s	remaining: 519ms
# 9969:	learn: 0.6139295	total: 2m 46s	remaining: 502ms
# 9970:	learn: 0.6139295	total: 2m 46s	remaining: 485ms
# 9971:	learn: 0.6139295	total: 2m 46s	remaining: 469ms
# 9972:	learn: 0.6139294	total: 2m 46s	remaining: 452ms
# 9973:	learn: 0.6139294	total: 2m 46s	remaining: 435ms
# 9974:	learn: 0.6139294	total: 2m 46s	remaining: 418ms
# 9975:	learn: 0.6139294	total: 2m 46s	remaining: 402ms
# 9976:	learn: 0.6139294	total: 2m 46s	remaining: 385ms
# 9977:	learn: 0.6139294	total: 2m 46s	remaining: 368ms
# 9978:	learn: 0.6139294	total: 2m 47s	remaining: 351ms
# 9979:	learn: 0.6139294	total: 2m 47s	remaining: 335ms
# 9980:	learn: 0.6139294	total: 2m 47s	remaining: 318ms
# 9981:	learn: 0.6139294	total: 2m 47s	remaining: 301ms
# 9982:	learn: 0.6139294	total: 2m 47s	remaining: 284ms
# 9983:	learn: 0.6139291	total: 2m 47s	remaining: 268ms
# 9984:	learn: 0.6139291	total: 2m 47s	remaining: 251ms
# 9985:	learn: 0.6139291	total: 2m 47s	remaining: 234ms
# 9986:	learn: 0.6139291	total: 2m 47s	remaining: 218ms
# 9987:	learn: 0.6139291	total: 2m 47s	remaining: 201ms
# 9988:	learn: 0.6139291	total: 2m 47s	remaining: 184ms
# 9989:	learn: 0.6139291	total: 2m 47s	remaining: 167ms
# 9990:	learn: 0.6139291	total: 2m 47s	remaining: 151ms
# 9991:	learn: 0.6139291	total: 2m 47s	remaining: 134ms
# 9992:	learn: 0.6139291	total: 2m 47s	remaining: 117ms
# 9993:	learn: 0.6139291	total: 2m 47s	remaining: 100ms
# 9994:	learn: 0.6139291	total: 2m 47s	remaining: 83.7ms
# 9995:	learn: 0.6139291	total: 2m 47s	remaining: 66.9ms
# 9996:	learn: 0.6139290	total: 2m 47s	remaining: 50.2ms
# 9997:	learn: 0.6139290	total: 2m 47s	remaining: 33.5ms
# 9998:	learn: 0.6139290	total: 2m 47s	remaining: 16.7ms
# 9999:	learn: 0.6139290	total: 2m 47s	remaining: 0us
# TransformedTargetRegressor(regressor=Pipeline(steps=[('second',
#                                                       ColumnTransformer(remainder='passthrough',
#                                                                         sparse_threshold=0.0,
#                                                                         transformers=[('ordinal',
#                                                                                        OrdinalEncoder(),
#                                                                                        [0,
#                                                                                         2,
#                                                                                         3,
#                                                                                         4,
#                                                                                         5])])),
#                                                      ('model',
#                                                       <catboost.core.CatBoostRegressor object at 0x000001CF2F0B6FD0>)]),
#                            transformer=PowerTransformer(method='box-cox'))

# %%
#fit LR
lin_pipe.fit(X_train, y_train)
# Out:
# TransformedTargetRegressor(regressor=Pipeline(steps=[('impute',
#                                                       ColumnTransformer(remainder='passthrough',
#                                                                         sparse_threshold=0.0,
#                                                                         transformers=[('imputer',
#                                                                                        SimpleImputer(strategy='most_frequent'),
#                                                                                        [0,
#                                                                                         1,
#                                                                                         2,
#                                                                                         3,
#                                                                                         4,
#                                                                                         5])])),
#                                                      ('second',
#                                                       ColumnTransformer(remainder='passthrough',
#                                                                         sparse_threshold=0.0,
#                                                                         transformers=[('one_hot',
#                                                                                        OneHotEncoder(),
#                                                                                        [0,
#                                                                                         2,
#                                                                                         3,
#                                                                                         4,
#                                                                                         5])])),
#                                                      ('model',
#                                                       LinearRegression())]),
#                            transformer=PowerTransformer(method='box-cox'))

# %%
# fit AdaBoost
ada_pipe.fit(X_train, y_train)
# Out:
# TransformedTargetRegressor(regressor=Pipeline(steps=[('impute',
#                                                       ColumnTransformer(remainder='passthrough',
#                                                                         sparse_threshold=0.0,
#                                                                         transformers=[('imputer',
#                                                                                        SimpleImputer(strategy='most_frequent'),
#                                                                                        [0,
#                                                                                         1,
#                                                                                         2,
#                                                                                         3,
#                                                                                         4,
#                                                                                         5])])),
#                                                      ('second',
#                                                       ColumnTransformer(remainder='passthrough',
#                                                                         sparse_threshold=0.0,
#                                                                         transformers=[('one_hot',
#                                                                                        OneHotEncoder(),
#                                                                                        [0,
#                                                                                         2,
#                                                                                         3,
#                                                                                         4,
#                                                                                         5])])),
#                                                      ('model',
#                                                       ExtraTreesRegressor(bootstrap=True,
#                                                                           criterion='friedman_mse',
#                                                                           n_estimators=1000))]),
#                            transformer=PowerTransformer(method='box-cox'))

# %%
# fit ExtraTrees
ada_pipe.fit(X_train, y_train)
# Out:
# TransformedTargetRegressor(regressor=Pipeline(steps=[('impute',
#                                                       ColumnTransformer(remainder='passthrough',
#                                                                         sparse_threshold=0.0,
#                                                                         transformers=[('imputer',
#                                                                                        SimpleImputer(strategy='most_frequent'),
#                                                                                        [0,
#                                                                                         1,
#                                                                                         2,
#                                                                                         3,
#                                                                                         4,
#                                                                                         5])])),
#                                                      ('second',
#                                                       ColumnTransformer(remainder='passthrough',
#                                                                         sparse_threshold=0.0,
#                                                                         transformers=[('one_hot',
#                                                                                        OneHotEncoder(),
#                                                                                        [0,
#                                                                                         2,
#                                                                                         3,
#                                                                                         4,
#                                                                                         5])])),
#                                                      ('model',
#                                                       ExtraTreesRegressor(bootstrap=True,
#                                                                           criterion='friedman_mse',
#                                                                           n_estimators=1000))]),
#                            transformer=PowerTransformer(method='box-cox'))

# %%
from lightgbm import LGBMRegressor

lgbm_pipe = generate_pipeline(
    LGBMRegressor(n_estimators=1000, learning_rate=0.05, num_leaves=31),
    column_indices,
    categorical_indices,
    fill_missing=True, one_hot=False, label_encode=True
)
lgbm_pipe = TransformedTargetRegressor(regressor=lgbm_pipe, transformer=PowerTransformer(method="box-cox"))

# %%
lgbm_pipe.fit(X_train, y_train)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006555 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 51
# [LightGBM] [Info] Number of data points in the train set: 72412, number of used features: 6
# [LightGBM] [Info] Start training from score 0.000000
# TransformedTargetRegressor(regressor=Pipeline(steps=[('impute',
#                                                       ColumnTransformer(remainder='passthrough',
#                                                                         sparse_threshold=0.0,
#                                                                         transformers=[('imputer',
#                                                                                        SimpleImputer(strategy='most_frequent'),
#                                                                                        [0,
#                                                                                         1,
#                                                                                         2,
#                                                                                         3,
#                                                                                         4,
#                                                                                         5])])),
#                                                      ('second',
#                                                       ColumnTransformer(remainder='passthrough',
#                                                                         sparse_threshold=0.0,
#                                                                         transformers=[('ordinal',
#                                                                                        OrdinalEncoder(),
#                                                                                        [0,
#                                                                                         2,
#                                                                                         3,
#                                                                                         4,
#                                                                                         5])])),
#                                                      ('model',
#                                                       LGBMRegressor(learning_rate=0.05,
#                                                                     n_estimators=1000))]),
#                            transformer=PowerTransformer(method='box-cox'))

# %%
from xgboost import XGBRegressor

xgb_pipe = generate_pipeline(
    XGBRegressor(n_estimators=1000, learning_rate=0.05, objective="reg:squarederror"),
    column_indices,
    categorical_indices,
    fill_missing=True, one_hot=False, label_encode=True
)
xgb_pipe = TransformedTargetRegressor(regressor=xgb_pipe, transformer=PowerTransformer(method="box-cox"))

# %%
xgb_pipe.fit(X_train, y_train)
# Out:
# TransformedTargetRegressor(regressor=Pipeline(steps=[('impute',
#                                                       ColumnTransformer(remainder='passthrough',
#                                                                         sparse_threshold=0.0,
#                                                                         transformers=[('imputer',
#                                                                                        SimpleImputer(strategy='most_frequent'),
#                                                                                        [0,
#                                                                                         1,
#                                                                                         2,
#                                                                                         3,
#                                                                                         4,
#                                                                                         5])])),
#                                                      ('second',
#                                                       ColumnTransformer(remainder='passthrough',
#                                                                         sparse_threshold=0.0,
#                                                                         transformers=[('ordinal',
#                                                                                        OrdinalEncoder(),
#                                                                                        [0,
#                                                                                         2,
#                                                                                         3,
#                                                                                         4,
#                                                                                         5])])),
#                                                      ('model',
#                                                       X...
#                                                                    interaction_constraints=None,
#                                                                    learning_rate=0.05,
#                                                                    max_bin=None,
#                                                                    max_cat_threshold=None,
#                                                                    max_cat_to_onehot=None,
#                                                                    max_delta_step=None,
#                                                                    max_depth=None,
#                                                                    max_leaves=None,
#                                                                    min_child_weight=None,
#                                                                    missing=nan,
#                                                                    monotone_constraints=None,
#                                                                    multi_strategy=None,
#                                                                    n_estimators=1000,
#                                                                    n_jobs=None,
#                                                                    num_parallel_tree=None,
#                                                                    random_state=None, ...))]),
#                            transformer=PowerTransformer(method='box-cox'))

# %%
from sklearn.svm import SVR

svr_pipe = generate_pipeline(
    SVR(kernel="rbf", C=100, gamma=0.1, epsilon=0.1),
    column_indices,
    categorical_indices,
    fill_missing=True, one_hot=True, label_encode=False
)
svr_pipe = TransformedTargetRegressor(regressor=svr_pipe, transformer=PowerTransformer(method="box-cox"))

# %%
svr_pipe.fit(X_train, y_train)
# Out:
# TransformedTargetRegressor(regressor=Pipeline(steps=[('impute',
#                                                       ColumnTransformer(remainder='passthrough',
#                                                                         sparse_threshold=0.0,
#                                                                         transformers=[('imputer',
#                                                                                        SimpleImputer(strategy='most_frequent'),
#                                                                                        [0,
#                                                                                         1,
#                                                                                         2,
#                                                                                         3,
#                                                                                         4,
#                                                                                         5])])),
#                                                      ('second',
#                                                       ColumnTransformer(remainder='passthrough',
#                                                                         sparse_threshold=0.0,
#                                                                         transformers=[('one_hot',
#                                                                                        OneHotEncoder(),
#                                                                                        [0,
#                                                                                         2,
#                                                                                         3,
#                                                                                         4,
#                                                                                         5])])),
#                                                      ('model',
#                                                       SVR(C=100, gamma=0.1))]),
#                            transformer=PowerTransformer(method='box-cox'))

# %%
from sklearn.neural_network import MLPRegressor

mlp_pipe = generate_pipeline(
    MLPRegressor(hidden_layer_sizes=(128, 64, 32), activation='relu', solver='adam', max_iter=500),
    column_indices,
    categorical_indices,
    fill_missing=True, one_hot=True, label_encode=False
)
mlp_pipe = TransformedTargetRegressor(regressor=mlp_pipe, transformer=PowerTransformer(method="box-cox"))

# %%
mlp_pipe.fit(X_train, y_train)
# Out:
# TransformedTargetRegressor(regressor=Pipeline(steps=[('impute',
#                                                       ColumnTransformer(remainder='passthrough',
#                                                                         sparse_threshold=0.0,
#                                                                         transformers=[('imputer',
#                                                                                        SimpleImputer(strategy='most_frequent'),
#                                                                                        [0,
#                                                                                         1,
#                                                                                         2,
#                                                                                         3,
#                                                                                         4,
#                                                                                         5])])),
#                                                      ('second',
#                                                       ColumnTransformer(remainder='passthrough',
#                                                                         sparse_threshold=0.0,
#                                                                         transformers=[('one_hot',
#                                                                                        OneHotEncoder(),
#                                                                                        [0,
#                                                                                         2,
#                                                                                         3,
#                                                                                         4,
#                                                                                         5])])),
#                                                      ('model',
#                                                       MLPRegressor(hidden_layer_sizes=(128,
#                                                                                        64,
#                                                                                        32),
#                                                                    max_iter=500))]),
#                            transformer=PowerTransformer(method='box-cox'))

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# 1. R2
#
# 2.RMSE

# %%
from sklearn.metrics import r2_score, mean_squared_error

# %%
def root_mean_squared_error(y_true, y_pred):
    value = mean_squared_error(y_true, y_pred)
    return np.sqrt(value)

# %%
def generate_model_score(model, data, metric_name, metric_function):
    X, y = data
    y_ = model.predict(X)
    score = metric_function(y, y_)
    return score

# %%
def print_metrics(metric_name, train_score, test_score):
    print(f"Train {metric_name} = {train_score}")
    print(f"Test {metric_name} = {test_score}")
    print(f"Generalization error = {train_score - test_score}")
    
    return

# %%
def test_model(model, data, metric_name, metric_function):
    train, test = data
    if isinstance(metric_name, str):
        train_score = generate_model_score(model, train, metric_name, metric_function)
        test_score = generate_model_score(model, test, metric_name, metric_function)
        print_metrics(metric_name, train_score, test_score)
        
    else: #multiple metrics
        for name, function in zip(metric_name, metric_function):
            train_score = generate_model_score(model, train, name, function)
            test_score = generate_model_score(model, test, name, function)
            print_metrics(name, train_score, test_score)
            
    return

# %%
#Name and functions for metrics
metric_name = ["R2", "RMSE"]
metric_function = [r2_score, root_mean_squared_error]

# %%
# create data variable
data_ =[
    [X_train, y_train],
    [X_test, y_test]
]

# %%
# Test CatBoost
test_model(cat_pipe, data_, metric_name, metric_function)
# Out:
# Train R2 = 0.3290481725222918
# Test R2 = 0.3114623180264121
# Generalization error = 0.017585854495879683
# Train RMSE = 365.83283765823745
# Test RMSE = 312.9020387367036
# Generalization error = 52.930798921533835

# %%
test_model(lin_pipe, data_, metric_name, metric_function)
# Out:
# Train R2 = 0.0692832344295512
# Test R2 = 0.08877540502075887
# Generalization error = -0.01949217059120767
# Train RMSE = 430.869531315598
# Test RMSE = 359.962494644653
# Generalization error = 70.90703667094499

# %%
test_model(ada_pipe, data_, metric_name, metric_function)
# Out:
# Train R2 = 0.22938830442641245
# Test R2 = 0.1881526346189364
# Generalization error = 0.04123566980747606
# Train RMSE = 392.0620565879021
# Test RMSE = 339.7674174069193
# Generalization error = 52.294639180982756

# %%
test_model(lgbm_pipe, data_, metric_name, metric_function)
# Out:
# Train R2 = 0.22156872590120835
# Test R2 = 0.18342489351884872
# Generalization error = 0.03814383238235963
# Train RMSE = 394.04620892990573
# Test RMSE = 340.75528818372027
# Generalization error = 53.29092074618546

# %%
test_model(xgb_pipe, data_, metric_name, metric_function)
# Out:
# Train R2 = 0.23011548421430328
# Test R2 = 0.1829420166781277
# Generalization error = 0.04717346753617557
# Train RMSE = 391.8770302676647
# Test RMSE = 340.8560251015761
# Generalization error = 51.02100516608857

# %%
test_model(mlp_pipe, data_, metric_name, metric_function)
# Out:
# Train R2 = 0.21279194001880908
# Test R2 = 0.20062059960389245
# Generalization error = 0.012171340414916632
# Train RMSE = 396.26141108639996
# Test RMSE = 337.148329777918
# Generalization error = 59.11308130848198

# %% [markdown]
# ### Model Deployment

# %% [markdown]
# Observation from the various models show that CatBoost Pipeline performed best amongst all models, The train score and the test score are close
#  while the (R2 score =0.32). The scores were still quite low or poor.The poor performce of the model is as a result of corrupt data and poorly imputed, leading to about 35% of the data lost.

# %% [markdown]
# ### Recommendation

# %% [markdown]
# A more cleaner data should be imputed to get a better performance of the model

# %%
###pip install mlflow
